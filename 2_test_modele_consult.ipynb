# %%
import pandas as pd
import numpy as np
import os
import warnings
import time

import json

from skrub import TableReport
from ollama import Client
from pdfquery import PDFQuery
from pprint import pprint

import bid_utils

# %%
## load the dfs built in 1_collect_files
rep_drive_ATAE =  r"C:\Users\jch_m\ATAE"
rep_data =        r"C:\DocPerso\Dev_Python\Data\ATAE"
rep_data_output = r"C:\DocPerso\Dev_Python\ProjetsPerso\BidManagement\data_output"

path_df_EBP = os.path.join(rep_data_output, "df_EBP.pkl")
df_EBP = pd.read_pickle(path_df_EBP)

path_df_consult = os.path.join(rep_data_output, "df_consult.pkl")
df_consult = pd.read_pickle(path_df_consult)

path_df_rejet = os.path.join(rep_data_output, "df_rejet.pkl")
df_rejet = pd.read_pickle(path_df_rejet)

# %%
# Merge df_consult and df_EBP pour sync EBP ID on the mission/files
# note: no need to sync EBP with rejet, because none of the Rejet file match an EBP entry (dans la liste des repertoires et fichiers). normal ?

# Define the columns to match on
match_columns = ['SPS Name', 'Ville', 'Entreprise', 'Mission']

df_consult_ebp = pd.merge(df_consult, df_EBP, on=match_columns, how='left', suffixes=('_consult', '_ebp'))
df_consult_ebp['ID EBP'] = df_consult_ebp['ID EBP_ebp'].fillna("no EBP")
df_consult_ebp = df_consult_ebp.drop(columns=['ID EBP_ebp','ID EBP_consult', 'statut_ebp'])

#df_consult_ebp['file_name'] = df_consult_ebp['file_path'].str.split(r'\\').str[-1].strip()
df_consult_ebp['file_name'] = df_consult_ebp['file_path'].str.split(r'\\').str[-1].str.strip()

# %%
# define a unique 'no EBP xx'  for each combinaison of SPS+Ville+Entreprise+Mission, for all related files
#
mask = df_consult_ebp["ID EBP"] == "no EBP"

# Create the combined series only for the masked rows
combined_series_for_update = (
    df_consult_ebp.loc[mask, 'SPS Name'].astype(str) + '_' +
    df_consult_ebp.loc[mask, 'Ville'].astype(str) + '_' +
    df_consult_ebp.loc[mask, 'Entreprise'].astype(str) + '_' +
    df_consult_ebp.loc[mask, 'Mission'].astype(str)
)

# Generate unique IDs for this series
unique_ids, _ = pd.factorize(combined_series_for_update)

# Assign back to the original DataFrame using the mask
df_consult_ebp.loc[mask, "ID EBP"] = "no EBP " + (unique_ids + 1).astype(str)

# %%
# Add columns "AO_docs" (True/False), "AO_Doc_type"(CCTP, CCAP, RC, AAPC, Memo_tech), "Commande"(True/False)

df_consult_ebp['AO_docs'] = (
    (df_consult_ebp['file_path'].str.lower().str.contains('devis') & df_consult_ebp['file_path'].str.lower().str.contains(r'\\consul')) | 
    (df_consult_ebp['file_path'].str.lower().str.contains(r'\\adm') & df_consult_ebp['file_path'].str.lower().str.contains(r'\\consul'))
)

# Set AO_doc_type
# Initialize all with default value
df_consult_ebp['AO_doc_type'] = 'no type'
mask = df_consult_ebp['AO_docs'] == True
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('CCTP', case=False, na=False), 'AO_doc_type'] = 'CCTP'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('CCP', case=False, na=False), 'AO_doc_type'] = 'CCTP'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('DCE', case=False, na=False), 'AO_doc_type'] = 'CCTP'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('Lettre', case=False, na=False), 'AO_doc_type'] = 'Lettre Consult'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('courier', case=False, na=False), 'AO_doc_type'] = 'Lettre Consult'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('consult', case=False, na=False), 'AO_doc_type'] = 'Lettre Consult'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('CCAP', case=False, na=False), 'AO_doc_type'] = 'CCAP'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('AAPC', case=False, na=False), 'AO_doc_type'] = 'AAPC'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('PA-', case=False, na=False), 'AO_doc_type'] = 'Procedure Adaptee'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('RC', case=False, na=False), 'AO_doc_type'] = 'RC'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('glement', case=False, na=False), 'AO_doc_type'] = 'RC'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('planning', case=False, na=False), 'AO_doc_type'] = 'Planning'
df_consult_ebp.loc[mask & df_consult_ebp['file_name'].str.contains('phasag', case=False, na=False), 'AO_doc_type'] = 'Planning'

# %%
list_file_AO_notype = ""
mask2 = (df_consult_ebp['AO_docs'] == True) &  (df_consult_ebp['AO_doc_type'] == 'no type')
list_file_AO_notype = df_consult_ebp.loc[mask2, 'file_name']
for file in list_file_AO_notype:
    if "plan " in file.lower() or "plans" in file.lower() or "coupe" in file.lower() or "vue" in file.lower() or "facade" in file.lower() or "lot" in file.lower():
        continue
    print(file)
# Out:
# Estimation ESQ-DIAG Modulaire Pierre et Marie Curie.pdf
# CSPS Contexte_Filières_HLX.pdf
# Heinlex Filieres-Programme-rev2.pdf
# 22062-PA8b-2023-06-22.pdf
# 2023-12-12-A1_existant.pdf
# 2023-12-12-A1_projet.pdf
# M22.054-CR01-20230907.pdf
# M22054-21-voirie.pdf
# Fiche identité CSPS.pdf
# Attestation 2021- 52-301 - SARL ATAE.pdf
# 2-Note méthodologique VENDEE EAU.pdf
# 3 DE SPS_230321 6 sites.pdf
# 3 DE SPS_230321 RECAPITULATIF.pdf
# 4-Attestation sur l'Honneur.pdf
# 5-Attestation Assurance 2021 ATAE.pdf
# 6-DC1.pdf
# 7-DC2 et annexes.pdf
# Programme technique.pdf
# ANNEXE tableau financier TVX base.pdf
# ANNEXE tableau financier TVX options.pdf
# AVP TOITURE CHLVO.pdf
# 03b DTA _  _ Travaux toiture Lege.pdf
# 04 Mémoire technique.pdf
# Mémoire technique Blandin Travaux toiture Lege.pdf
# Cahier charges mission CSPS_Boucardière - ATAE.pdf
# Cahier charges mission CSPS_Boucardière.pdf
# MACHECOUL - MASSE - 2017 02 28.pdf
# MACHECOUL - MASSE - 2017 02 28.pdf
# 00-Courriersolicitation.pdf
# 02 Ficherenseignements SPS.pdf
# 04-BPU_Petit-Gast&Beausoleil.pdf
# 05-DE_Petit-Gast&Beausoleil.pdf
# B6-Profils en long.pdf
# A6-Profils en long.pdf
# MAP M. DAVID et Mme AZIADAPOU.PDF
# 635 CAHIER DES CHARGES.pdf
# 640-22A - AVP -  RESTRUCTURATION REFECTOIRE - NOTICE.pdf
# 640-22A - AVP -  RESTRUCTURATION REFECTOIRE - NOTICE.pdf
# Jean-Paul Renaud demolitions.pdf
# Jean-Paul Renaud PC V2.pdf
# Jean-Paul Renaud plan.pdf
# 05-Schéma de distribution intérieur.pdf
# Retour visite APS_Piscine Challans_12 12 2022_V1.pdf
# 2022-04-08 PC RABREAU.pdf
# 2022-07-06 APD CAMAX-a1.pdf
# Le St Eloi - Construction d'une résidence - AT_ST_ELOI_COMPLET.pdf
# Le St Eloi - Construction d'une résidence - AT_ST_ELOI_COMPLET.pdf
# 0148_001.pdf
# PC SCI PERRIN.pdf
# EXTENSION SOCOVA TP _ LISTE ENTREPRISES.pdf
# Cinéma_Démolition_Programme.pdf
# 12.025-CC CSPS.pdf
# IDN_VIAB_PRO_PRES-PLN_masse_général_A3-1000.pdf
# 01a_Offre technique_VENDEE EAU_CAG THM_V2.pdf
# Attestation 2021- 52-301 - SARL ATAE.pdf
# 2-Note méthodologique VENDEE EAU.pdf
# 3 DE SPS_230321 6 sites.pdf
# 3 DE SPS_230321 RECAPITULATIF.pdf
# 4-Attestation sur l'Honneur.pdf
# 5-Attestation Assurance 2021 ATAE.pdf
# 6-DC1.pdf
# 7-DC2 et annexes.pdf
# SKM_C30823021317010.pdf
# 20161-Topo.pdf
# 210218 MASSE 19-01-21 - version Podeliha.pdf
# 210609 Convention de rétrocession signée.pdf
# 210609 Délibération municipale approuvant la rétrocession.pdf
# 210825 Annexes Arrêté obtention PC.pdf
# 210825 Arrêté obtention PC.pdf
# 210825 Pièce graphiques PC signées mairie.pdf
# planCadastralNormalise (1).pdf
# SCI BIOACADIE - EXE - 2024 01 05.pdf
# SCI BIOACADIE - EXE - 2024 01 05.pdf
# DossierPC_OLA-0067_BignonCTM.pdf
# Travaux envisagés - 12 rue Gazonnière CHALLANS.pdf
# AUDIT RAPPORT VD- LES BOSQUETS - HABITAT & HUMANISME.pdf
# Prog tx - Margueritte CHALLANS.pdf
# 04-Schema de Principe - Maison d'Habitation.pdf
# 05-Schema de Principe - Dépendance.pdf
# 20221219 AVOCETTE-Projet zone 1 A3.pdf
# 20221219 AVOCETTE-Projet zone 2 A3.pdf
# Annexe 04 - Photo Aérienne.pdf
# Programme Opération 18-03-2021b.pdf
# 0092-054 PTC 18_05_2022.pdf
# 0092-055 PTC 20_05_2022.pdf
# 24-001 CHALLANS CUVE EP AVEC PAYSALIS.pdf
# 2021 03 30 FAISABILITE - Construction d'une résidence - AP_10_COMPLET.PDF
# CARNET ESQ2.pdf
# 22-01-06 Albert 1er Challans.pdf
# APD.pdf
# DossierPC_OLA-0070_LegeCS.pdf
# DossierPC_OLA-0069_LegeVerne.pdf
# Avant-Projet Détaillé Château février 2021.pdf
# A0 RDC R+1 PRO.pdf
# A3 MASSE PRO.pdf
# ELEVATIONS PRO.pdf
# 1- PC1 - CARTOUCHE - SITUATION_31.pdf
# 1- PC1 - CARTOUCHE - SITUATION_31.pdf
# 2- PC2 - PROJET - MASSE 1.500 1.250_32.pdf
# 2- PC2 - PROJET - MASSE 1.500 1.250_32.pdf
# Notice descriptive  - THEPAUT - MACHECOUL-ST MEME.pdf
# Notice descriptive  - THEPAUT - MACHECOUL-ST MEME.pdf
# BPU_2020210017_03.pdf
# Memo mission SPS.pdf
# ZR23-24_FLORALIES-PRO1 - A0 SITE GENERAL- 20231030L - Copie.pdf
# ZR23-24_FLORALIES-PRO1 - A0 SITE GENERAL- 20231030L - Copie.pdf
# R240204_Devoiement ERENA_ZONE01-04_PRO_ZONE 1_prov.pdf
# PRO_E240105-ZAC-27_06_2024_Ind.0-PRO.pdf
# Programme Espace BONNAMY 12 04 2022.pdf
# RSSPLB13831-05b PG ZPC phase 1 les isles_opérateurs.pdf
# Liste_artisans_pour promo MAJELLI_0165 HAMEAU DES FIGUIERS.pdf
# 2023-03-06 PC SC DES GALERIES.pdf
# Agrandissement et réaménagement d'un magasin de vente de produits frais - VV_YOLEUR_PC_COMPLET.pdf
# EXTRAIT CADASTRAL.pdf
# MA2308_Annexe_1_Expertise_locaux_suite_incendie.pdf
# MA2308_Annexe_2_Diagnostic_amiante.pdf
# MA2308_Annexe_3_plan_rdc.pdf
# MA2308_Annexe_4_plan_toiture.pdf
# DossierPC-VersionDef_OLA-071_SaintPhilbertCollege.pdf
# DossierPC-VersionDef_OLA-072_SaintPhilbertPiscine.pdf
# C230178 - ST SEB - MAIRIE - Réno intérieure écoles PPI 2023.pdf
# C230178 - ST SEB - MAIRIE - Réno intérieure écoles PPI 2023.pdf
# CSPS_PPI ete 2024.pdf
# DOSSIER GRAPHIQUES.pdf
# DOSSIER GRAPHIQUES.pdf
# NOTE DE PRESENTATION.pdf
# NOTE DE PRESENTATION.pdf
# PC01 MULARD ORVIA 230727.pdf
# PC02 MULARD ORVIA 230727.pdf
# PC03 MULARD ORVIA 230727.pdf
# PC04 MULARD ORVIA 230727.pdf
# PC05 existant MULARD ORVIA 230727.pdf
# PC05 projet MULARD ORVIA 230727.pdf
# PC06 MULARD ORVIA 230727.pdf
# PC0708 MULARD ORVIA 230727.pdf
# OLA-0063_VieilleVigne - Autorisation Urbanisme.pdf
# OLA-0063_VieilleVigne - Dossier PC.pdf
# Cahier des charges mission SPS.pdf
# 230428_22diag_231115_diagnostic salle Henri IV.pdf
# 230428_22diag_231115_estimation.pdf
# 20323 PC Vlok Niort validé.pdf
# 2 CahierdeschargesvalantAE CSPS GiratoirePont-James.pdf
# 3 PRO_petite Denisiere_CL2 St Gervais.pdf
# SPS3_DENISIERE_ST Gervais MAJ_161023.pdf
# 2022-08-24 - SAINT GILLES CROIX DE VIE - estimations - détail local.pdf
# 2022-08-24 - SAINT GILLES CROIX DE VIE - estimations - détail local.pdf
# CR n°6 Ad'ap 2022.pdf
# 2022.29_220027A_STEP_St-Philbert_CC_Coordination-SPS.pdf
# 7 - Calendrier des études et des travaux.pdf
# Note de présentation.pdf
# MS20.005-20-1 - DEPOLLUTION - B.pdf
# MS20.005-20-2 - ETAT ACTUEL - B.pdf
# MS20.005-21-1 - VOIRIE.pdf
# MS20.005-21-2-TSST.pdf
# MS20.005-22 - B.pdf
# Situation.pdf
# 150520_MULTI-ACCUEIL-PROG.pdf
# 210521_MA-APS.pdf
# 210521_MA-SPS-COU.pdf
# 2021 - 02GI - AE CSPS - Façades et thermies.pdf
# 2021.02GI Livret prestataire.pdf
# 2021.02GI_Contrat de confidentialité.pdf
# PROGRAMME TECHNIQUE FINAL.pdf
# 2021 - 02GI - AE CSPS - Façades et thermies.pdf
# 2021.02GI Livret prestataire.pdf
# 2021.02GI_Contrat de confidentialité.pdf
# PROGRAMME TECHNIQUE FINAL.pdf
# Affaire A320347484_Immeuble Allende_ Repérage Amiante avant travaux.pdf
# Fiche identité opération Allende - CSPS.PDF
# Programme.pdf
# Plan_01_Sud_exist.pdf
# Plan_02_Sud_prjt.pdf
# Plan_03_Mediant_ex_pjt.pdf
# Plan_04_Nord_exist.pdf
# Plan_05_Nord_prjt.pdf
# CAHIER DES CHARGES TECHNIQUES PARTICULIERES.pdf
# AE CSPS.pdf
# PROG TRAVAUX.pdf
# Devis ATAE CSPS - PROJET LES HERBIERS - Av de Cholet.pdf
# Devis ATAE CSPS - PROJET LES HERBIERS - Av de Cholet.pdf
# FAISABILITE V2.pdf
# 2221_20220126_ESQ02.pdf
# 14361 PA1.pdf
# 14361 PA4.pdf
# 14361-Projet 2019-PA8a.pdf
# Désignation référents.pdf
# Programme.pdf
# LACOUTURE-EGLISENDASSOMPTION.pdf
# FdJ Martinet - CC et programme de l'opération.pdf
# AE SPS MORTAGNE SUR SEVRE.pdf
# CR 02.pdf
# ATAE.pdf
# IMG_0001.pdf
# Diag amiante avant demol 2021.pdf
# Notice descriptive de l'opération.pdf
# Présentation Pont Morineau ORYON.pdf
# Affaire A320448821_Repérage Amiante avant démolition _Maison d'habitation 9 Rue Monthulet.pdf
# Affaire A320448821_Repérage Amiante avant démolition - Maison d'habitation - 9Bis-11-11Bis Rue Monthulet.pdf
# Affaire A320448821_Repérage Amiante avant démolition - MAISON DE QUARTIER - 16 Rue Roger Salengro .pdf
# Programme MOE - Réaménagement La Jarrie.pdf
# D202202507.pdf
# DP Maison du Meunier.pdf
# 202239_COURRIER_SPS_EPINASSE.pdf
# Fiche identité SPS LGMTS Le Tablier.pdf
# img20220520_10280614.pdf
# img20220520_10285896.pdf
# Compil PRO2 en cours Kinés EBM 220222.pdf
# ATAE CSPS - DEVIS 220946 - BELLEVIGNY - GFA BETHI - Maison de l'Etang.pdf
# ATAE CSPS - DEVIS 220946 - BELLEVIGNY - GFA BETHI - Maison de l'Etang.pdf
# Les Clouzeaux ESQ.pdf
# 040722_EEB2214-PRESENTATION.pdf
# 211214 - EXE - RUE DU CENTRE 01.pdf
# 211214 - EXE pour MAP - RUE DU CENTRE 02.pdf
# 211007 - LE PETIT BOSQUET LOGT 4 - EXE pour MAP.pdf
# 2205-SATOV B23-Dossier APS.PDF
# 4000.pdf
# EXE M et Mme BLONDET.PDF
# 1-PC-VESTIAIRES DECHETERIE-JARD-231221.pdf
# 2-PC-VESTIAIRES DECHETERIE-JARD-231221.pdf
# Mission SPS_EXE VEFA MAISON SATOV 290622.pdf
# 1ER ETAGE.pdf
# 5001 impression.pdf
# RDC.pdf
# TEMPS TACHE.pdf
# Devis corrigé ATAE SPS CENTRE HOSPITALIER G. MAZURELLE PLAFONDS SUSPENDUS.pdf
# 01-03-2022 - Faisabilité 3 - RDC.pdf
# 01-03-2022 - Faisabilité 3 - RDC.pdf
# Courrier de cessation.pdf
# Devis.pdf
# 2242 - ESQ - AVRILLAS P. - 14.11.22.pdf
# 2242 - ESQ - AVRILLAS P. - 14.11.22.pdf
# EXE ST MATHURIN 17 01 2022.pdf
# 2 Formulaire PC.pdf
# courrier modif.pdf
# Mai 2022 - Note hydraulique - ZAE CHAMPROVENT.pdf
# Mai 2022 - Note hydraulique - ZAE CHAMPROVENT.pdf
# NOTICE~1.PDF
# PC.0 _ Masse Implantation_12.pdf
# PC.1 _ Page de Garde_11.pdf
# PC.2 _ Masse côtes_13.pdf
# PC.2 _ Masse Réseaux_14.pdf
# PC.4 Notice Paysagère_22.pdf
# PC.5 _ Façades Bat A_24.pdf
# PC.5 _ Façades Bat B_25.pdf
# PC.5 _ Masse Toiture_23.pdf
# PC.6 _ Insertion_28.pdf
# PC.7 et 8 _ Photographies_29.pdf
# PLANMA~1.PDF
# PLANPR~1.PDF
# texte modificatif.pdf
# PC SAS AC Contruction - 2 Logements.pdf
# PA1 - Situation.pdf
# PROGRAMME SPS 2785 07.01.22.pdf
# Réponse DPGF.pdf
# SPS - ATAE.pdf
# 23 PM ap W.pdf
# 23 PM av W.pdf
# ATAE.pdf
# 03_4550688_PRO_Mise en séparatif_INDC-Rue du 8 Mai_Profil 01C.pdf
# 08_4550688_PRO_Mise en séparatif_INDC-Rues De Lattre & Pasteur_Plan_04A.pdf
# 09bis_4550688_PRO_Mise en séparatif_INDD-Rues De Lattre & Pasteur_Plan_04B.pdf
# 10bis_4550688_PRO_Mise en séparatif_INDD-Rues De Lattre & Pasteur_Plan_04C.pdf
# 11_4550688_PRO_Mise en séparatif_INDC-Rue de L'Europe_Plan_05A.pdf
# 12bis_4550688_PRO_Mise en séparatif_INDD-Rue de L'Europe_Plan_05B.pdf
# 13bis_4550688_PRO_Mise en séparatif_INDD-Rue de L'Europe_Profils_05C.pdf
# 15_4550688_PRO_Mise en séparatif_INDC-Rue des Tisserands_Plan&profils 06B.pdf
# 16_4550688_PRO_Mise en séparatif_INDC-Rue des Marronniers 07A.pdf
# 17_4550688_PRO_Mise en séparatif_INDC-Rue des Marronniers 07B.pdf
# 19_4550688_PRO_Mise en séparatif_INDC-Rue de la Cour_Plan&Profils 08B.pdf
# 20221005_RAAT_Viete_global.pdf
# 4412060_1702435 - G1 PGC  - Extension collège - Fontenay Le Compte (85).pdf
# Diagnostic Collège F VIETE.pdf
# Viete_Notice descriptive.pdf
# 2023-04-06 - Notice descriptive estimative ESQ - LPSV com com Bat Stock (1).pdf
# LE POIRE Batiment Stockage (1).pdf
# 20230519122110.pdf
# A1_DTA et plomb.pdf
# A3_programme MOE rénovation.pdf
# cahier des charges CSPS_rénovation Halles Centrales.pdf
# Notice descriptive CT SPS ST GILLES.pdf
# 19186-AVP-Giration-Gir BOM PL1.pdf
# 19186-AVP-Giration-Gir BOM PL2.pdf
# 19186-AVP-Giration-Gir PAV PL1.pdf
# 19186-AVP-Giration-Gir PAV PL2.pdf
# 19186-PRO T1-EA P1_c.pdf
# 19186-PRO T1-EA P2_c.pdf
# 19186-PRO T1-EA P3_c.pdf
# 19186-PRO T1-EA P4_c.pdf
# 19186-PRO T1-EA P5_c.pdf
# 19186-PRO T1-EA P6_c.pdf
# 19186-PRO T1-EA P7_c.pdf
# 19186-PRO T1-RES P1_c.pdf
# 19186-PRO T1-RES P2_c.pdf
# 19186-PRO T1-RES P3_c.pdf
# 19186-PRO T1-RES P4_c.pdf
# 19186-PRO T1-RES P5_c.pdf
# 19186-PRO T1-RES P6_c.pdf
# 19186-PRO T1-RES P7_c.pdf
# 19186-PRO T1 VOI P1_c.pdf
# 19186-PRO T1 VOI P2_c.pdf
# 19186-PRO T1 VOI P3_c.pdf
# 19186-PRO T1 VOI P4_c.pdf
# 19186-PRO T1 VOI P5_c.pdf
# 19186-PRO T1 VOI P6_c.pdf
# 19186-PRO T1 VOI P7_c.pdf
# 2101L 05-PRO 2023 04 26 A0 Exist PM-Situ.pdf
# 2101L 05-PRO 2023 04 26 A0 Projet PM-Situ.pdf
# 2101L 05-PRO 2023 04 26 A1 Projet Bar et sanitaires.pdf
# 2101L 05-PRO 2023 04 26 A1 Projet Sanitaires.pdf
# Rapport d'étude d'assainissement 10324 - DOMAINE DES VILLATES - CHANTONNAY.pdf
# Rapport d'étude d'assainissement 10324 - DOMAINE DES VILLATES - CHANTONNAY.pdf
# 01-01 Page de Garde.pdf
# 01-02 Situation - Cadastre.pdf
# 01-08 Façades N_S - Existant Bât E.pdf
# 01-09 Façades O_E - Existant Bât E.pdf
# 01-10 Façades N_S - Projet Bât E.pdf
# 01-11 Façades O_E - PROJET Bât E.pdf
# 01-12 Façades N_S - EXISTANT Bât F.pdf
# 01-13 Façades O_E - EXISTANT Bât F.pdf
# 01-14 Façades N_S - PROJET Bât F.pdf
# 01-15 Façades N_S - PROJET EXTENSION.pdf
# 01-16 Façades O_E - PROJET Bât F + Extension.pdf
# 01-17 Insertion Paysagère, Perspective - Projet.pdf
# 01-18 Paysage lointain -  Environnement proche - Bât E.pdf
# 01-19 Paysage lointain -  Environnement proche - Bât F.pdf
# 230328_CFA NATURE - AVP.pdf
# Estimation TCE ESQ du 01.03.23.pdf
# 2022.10.17 - Avant-Projet - 2ème scanner.pdf
# 2022.10.17 - Avant-Projet - 2ème scanner.pdf
# 05 PRO 2023-10-23 01B02-Aviron85 - Modification Vestiaires.pdf
# A1_programme MOE relocalisation.pdf
# cahier des charges CSPS_reloc.pdf
# ATAE.pdf
# programme.pdf
# PROGRAMME DES TRAVAUX LES JASMINS  22-027.pdf
# PLANCHE PRO provisoire_01_EXISTANT.pdf
# Plan_LaTonnelle_ProtectionCathodique.pdf
# Plan_MaraisSalé_ProtectionCathodique.pdf
# 17386528 - 85 - LES SABLES D'OLONNE - BD ARAGO - AMENROB + HAP.pdf
# 17386528 - 85 - LES SABLES D'OLONNE - BD ARAGO - AMENROB + HAP.pdf
# Cahier des Charges.pdf
# MISSION CSPS - DESIGNATION REFERENTS.pdf
# H69-079_PCM_BATIMENT 1.pdf
# H69-079_PCM_BATIMENT 2.pdf
# H69-RsY_210915_ESQUISSE_250em_A3.pdf
# H69-RsY_210915_PERS ESQUISSE_A3.pdf
# 221115 Presentation succinte V0.pdf
# 40719 - 01 MASSE A2.pdf
# TOUS CORPS D'ETAT.pdf
# Liste des intervenants - VEFA LES ROCHELLES.PDF
# Bon de cde ATE signé.PDF
# Programme-Maillezais-securisation.pdf
# 20230726 0211-MSM LA GRIMOIRE PTC.pdf
# Liste des intervenants.pdf
# Devis ATAE CSPS - Eiffage - Dépollution du site de la Roche sur Yon.pdf
# Devis ATAE CSPS - Eiffage - Dépollution du site de la Roche sur Yon.pdf
# 03-PRO 2024-02-27 Sanitaires Mat.pdf
# Devis Quantitatif.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-COMBLES.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-FONDATIONS.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-PH R+1.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-PH R+2.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-PH R+3.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-PH RDC.pdf
# 4518 EHPAD du Moulin Rouge - La Roche Sur Yon - Note acoustique PRO.pdf
# 038- EHPAD  CCF-PRO.pdf
# 214079 - BEGC PRO IMPLANTATION.pdf
# 214079 - BEGC PRO RESERVATION.pdf
# ATAE-PGC 14.192 du 15-09-15.pdf
# IGESOL-Rapport géotechnique-février 2015.pdf
# ORTEC-Inspection réseau EP-mars 2015.pdf
# ORTEC-Inspection réseau EU-mars 2015.pdf
# PRIMMODIAG-Diagnostic amiante avant travaux-sept 2014.pdf
# PRIMMODIAG-Diagnostic technique amiante-sept 2014.pdf
# SOCOTEC-Etude acoustique environnementale-avril 2015.pdf
# SOCOTEC-RICT du 08-09-2015 - SQ_6293354.pdf
# 1446-Pro-Liste des pièces du 15-07-2015.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-COMBLES.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-FONDATIONS.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-PH R+1.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-PH R+2.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-PH R+3.pdf
# 14.03.826-AP-BA-EHPAD du MOULIN ROUGE-PH RDC.pdf
# 968 - Carnet désenfumage PRO DES.pdf
# 4518 EHPAD du Moulin Rouge - La Roche Sur Yon - Note acoustique PRO.pdf
# 038- EHPAD  CCF-PRO.pdf
# ZS0 juillet15.pdf
# ZS1 juillet15.pdf
# ZS2 juillet15.pdf
# ZS3 juillet15.pdf
# ZS4 juillet15.pdf
# 214079 - BEGC PRO IMPLANTATION.pdf
# 214079 - BEGC PRO RESERVATION.pdf
# 0-Programme des travaux (définitif au 20-03-2014).pdf
# 1-Rapport vérif élec SOCOTEC du 18-12-2009 pour FPA du MR.pdf
# 10-Généralités de fonctionnement installations de régulation des bâtments communaux.pdf
# 11-Cahier des charges des cablages des bâtments communaux.pdf
# 2-Rapport vérif élec SOCOTEC du 07-12-2010 pour FPA du MR.pdf
# 3-Rapport DSV sur cuisine FPA du 24-11-2010 pour FPA du MR.pdf
# 6-Rapport diag accessibilité SOCOTEC du 15-04-2011 pour FPA du MR.pdf
# 8a-Rapport amiante APAVE du 30-12-2005 et ses annexes pour FPA du MR.pdf
# 8b-Dossier technique amiante APAVE du 30-12-2005-Fiche récap du DTA pour FPA du MR.pdf
# 9-Diagnostic amiante PRIMODIAG du 11-06-2012 pour FPA du MR.pdf
# Cahier des charges alarme des batiments communaux.pdf
# Modificatifs et compléments au programme (2014-11-20).pdf
# Fiche identité CT & SPS.pdf
# 210728 - DOMAINE DES MIMOSAS - EXE.PDF
# 210728 - DOMAINE DES MIMOSAS - EXE.PDF
# Liste des intervenants - VEFA MIMOSAS.PDF
# BatiMgie-CdP-APD-ST HILAIRE LE VOUHIS-CHAUF BOIS MAIRIE ET GS PRIM.pdf
# CHAUFFERIE BOIS MISSION SPS.pdf
# PC SAS AC Contruction - 2 Logements.pdf
# Courrier ATAE.pdf
# plan02_Assmt_Existant.pdf
# plan03_Assmt_Projet.pdf
# EXE 1a - HAMEAU MARGUERITE - Le 03-03-2022.pdf
# EXE 1a - HAMEAU MARGUERITE - Le 03-03-2022.pdf
# Attestation 2021- 52-301 - SARL ATAE.pdf
# 2-Note méthodologique VENDEE EAU.pdf
# 3 DE SPS_230321 6 sites.pdf
# 3 DE SPS_230321 RECAPITULATIF.pdf
# 4-Attestation sur l'Honneur.pdf
# 5-Attestation Assurance 2021 ATAE.pdf
# 6-DC1.pdf
# 7-DC2 et annexes.pdf
# DP1 - SITUATION_4081.pdf
# DP2 - MASSE PROJET_4083.pdf
# AVP_C_NEMROD.pdf
# Situation du projet.pdf
# Attestation 2021- 52-301 - SARL ATAE.pdf
# 2-Note méthodologique VENDEE EAU.pdf
# 3 DE SPS_230321 6 sites.pdf
# 3 DE SPS_230321 RECAPITULATIF.pdf
# 4-Attestation sur l'Honneur.pdf
# 5-Attestation Assurance 2021 ATAE.pdf
# 6-DC1.pdf
# 7-DC2 et annexes.pdf
# RD01_0_2209105 Rapport de diagnostic_IDES_221107_121932.pdf
# 1-PC-VESTIAIRES DECHETERIE-JARD-231221.pdf
# 2-PC-VESTIAIRES DECHETERIE-JARD-231221.pdf
# AVP-Espace de Loisirs-v6-sans bassin.pdf
# P210362 - MOUILLERON Local Association - AP3 27.04.2022_compressed.pdf
# P210362 - MOUILLERON Local Association - AP3 27.04.2022_compressed.pdf
# 20210902_PTC_ ZAC MULTI-SITES.PDF
# Liste des intervenants - VEFA MARTINIERE.PDF
# ATAE CSPS - DEVIS 230328 - RSY - MAIRIE - Bureau cimetière La Peronière.pdf
# ATAE CSPS - DEVIS 230328 - RSY - MAIRIE - Bureau cimetière La Peronière.pdf
# CMS - ESQ validé 2023-01-18.pdf
# Estimation- Démolition désamiantage - Galeries Bonaparte.pdf
# Estimation- Démolition désamiantage - Galeries Bonaparte.pdf
# 03 Carnet PRO.pdf
# EXE Logt 160.pdf
# EXE Logt 165.pdf
# Attestation 2021- 52-301 - SARL ATAE.pdf
# 2-Note méthodologique VENDEE EAU.pdf
# 3 DE SPS_230321 6 sites.pdf
# 3 DE SPS_230321 RECAPITULATIF.pdf
# 4-Attestation sur l'Honneur.pdf
# 5-Attestation Assurance 2021 ATAE.pdf
# 6-DC1.pdf
# 7-DC2 et annexes.pdf
# S5328 SITUATION.pdf
# PUBsimplifiee.pdf
# 1583829008sq2pskepz8l5_LET_ATTRIBUTAIRE_ATAE.pdf
# COUVERTURES-DPGF.pdf
# MOE Marie de Beaucaire - Modifié.pdf
# CHAUCIDOU AUBRAIS.pdf
# 0087 - cahier des charges CT  SPS.pdf
# Devis CSPS ATAE - SVS - MAIRIE - Rénovation énergétique périscolaire.pdf
# Devis CSPS ATAE - SVS - MAIRIE - Rénovation énergétique périscolaire.pdf
# Note Méthodologique ST VINCENT STERLANGES.pdf
# 2254-85-01-01-C EQ01-IndB-Equipements filtres.pdf
# 2254-85-01-01-C IMP01-IndB - Implantation.pdf
# C22320-85 Mémoire technique V1.0.pdf
# PPSPS Roturier.pdf
# 19F212-PRO-CG-DIG-014A.pdf
# 19F212-PRO-CG-DIG-015A.pdf
# 19F212-PRO-CG-DIG-016A.pdf
# 19F212-PRO-PG-DIG-011A.pdf
# 19F212-PRO-PG-DIG-012A.pdf
# 19F212-PRO-PG-DIG-013A.pdf
# Noticedesouvrages.pdf
# PLANDESITUATION.pdf
# COURRIER ATAE BRETIGNOLLES.pdf
# Partie-Basse.pdf
# Partie-Basse1.pdf
# Partie-Haute.pdf
# Partie-Haute1.pdf
# Profil en long Sauzaie.pdf
# Profil en long Traversée.pdf
# Traversée1.pdf
# APD NOTICE DESCRIP ESTIM 2 ATELIERS CDC CHANTONNAY.pdf
# CdC Pays de CHANTONNAY  2 ateliers A0 - APD'.pdf
# AVP.pdf
# EXE 1a - VEFA PYRUS - le 01-02-23.pdf
# EXE 1a - VEFA PYRUS - le 01-02-23.pdf
# Liste des intervenants.pdf
# SOUDE_JAUNAY_CSPS_CC.pdf
# 2021_09_PLAN_LogisBeaupuy ESQ - présentation.pdf
# 2023-06-22 ESQ O TEL PARK-compressé.pdf
# 2023-12-08 09 AT7.pdf
# 2023-12-08 11 AT8.pdf
# 2023-12-08 12 AT8.pdf
# 2023-12-08 17 AT9.pdf
# 2023-12-08 18 AT9.pdf
# 2023-12-08 19 AT9.pdf
# APPEL D'OFFRE A TELECHARGER.pdf
# ETUDE DE FAISABILITE 13 décembre 2023.pdf
# ETUDE DE FAISABILITE dec 2023.pdf
# EXE 1d - VEFA DOMAINE SOIVRE - Le 10-10-2022.pdf
# EXE 1d - VEFA DOMAINE SOIVRE - Le 10-10-2022.pdf
# Liste des intervenants.pdf
# EXE2 VEFA SATOV - 2 IMPASSE DES COLIBRIS.pdf
# DP CHANTIER SUI GENERIS - OLONNE SUR MER.pdf
# RJ 18 du 31 Octobre 2019.pdf
# Annexe 1 Notre Dame de Riez_C2.pdf
# Annexe 3 PLAN-RESEAUX.pdf
# Annexe 4 Poste le Fenouiller_D2.pdf
# Annexe 5 Poste le Fenouiller_MASSE_D.pdf
# Annnexe 2 Notre Dame de Riez_MASSE.pdf
# SALLE DE SPECTACLE LA BALISE word.pdf
# DTA Complément salle de la Vie.pdf
# DTA salle de la Vie.pdf
# OPS ESQ - 30 11 2022.pdf
# courrier atae st hilaire.pdf
# Pro_Clem_300_pl1.pdf
# Pro_Clem_300_pl2.pdf
# Pro_Clem_300_pl3.pdf
# Pro_Disque_300_plA.pdf
# Pro_Disque_300_plB.pdf
# Liste des intervenants.pdf
# Mission SPS Accueil Groupe du Moulin des Gourmands.pdf
# Annexe-projet 2 Mairie.Poste_CSPS.pdf
# 4- Note programme Clémenceau.pdf
# Fiche identité opération Venansault Centre-Bourg.pdf
# L20168-ind-A.pdf
# L20168-ind-B.pdf
# DPGF à compléter.pdf
# DSY-Ecole Pierre Menanteau-MOE-programme.pdf
# DSY-Ecole Pierre Menanteau-MOE-programme.pdf
# PROJET STEVEN 2024- CHAPI CHAPO démolition.pdf
# PROJET STEVEN 2024- CHAPI CHAPO projet.pdf
# BPU CSPS 2024 - 2025.pdf
# FAISA RIVES DE YON V2.pdf
# 24 182 ATAE.pdf
# VERITAS_Diagnostic plomb A0.pdf
# VERITAS_1-Pré-rapport-amiante-avant-travaux.pdf
# VERITAS_2-annexe_Rapport-anlalyse labo B0.pdf
# VERITAS_3-Plan-repérage-amiante B0.pdf
# APAVE_~1.PDF
# VERITAS_Pré-rapport amiante avant travaux.pdf
# courrier SPS 03-06-24.pdf
# Attestation 2021- 52-301 - SARL ATAE.pdf
# Attestation 2021- 52-301 - SARL ATAE.pdf
# 2-Note méthodologique VENDEE EAU.pdf
# 2-Note méthodologique VENDEE EAU.pdf
# 3 DE SPS_230321 6 sites.pdf
# 3 DE SPS_230321 6 sites.pdf
# 3 DE SPS_230321 RECAPITULATIF.pdf
# 3 DE SPS_230321 RECAPITULATIF.pdf
# 4-Attestation sur l'Honneur.pdf
# 4-Attestation sur l'Honneur.pdf
# 5-Attestation Assurance 2021 ATAE.pdf
# 5-Attestation Assurance 2021 ATAE.pdf
# 6-DC1.pdf
# 6-DC1.pdf
# 7-DC2 et annexes.pdf
# 7-DC2 et annexes.pdf
# Ste Hermine Notice descriptive.pdf
# 02-AE-SPS_cat2 et 3.pdf
# Annexe-1-2024_Organisation_Alimentation.pdf
# SPS Cadre Memoire technique.pdf
# 304-24 APS 241128.pdf
# CC_SPS_LD.pdf
# 6225260_C_ASS EP.pdf
# 6225260_C_ESPACES VERTS.pdf
# 6225260_C_MASSE.pdf
# 6225260_C_PROFIL.pdf
# 6225260_C_SECTEURS.pdf
# 6225260_C_SIGNA.pdf
# 6225260_C_TVB.pdf
# 6225260_C_TVX.pdf
# 2023-10_PRO_ST MEEN Chapelle-PIECES GRAPHIQUES.pdf
# Calendrier Prévisionnel 240905.pdf
# PRO-RAPPORT DE PRESENTATION OCT 2023.pdf
# SMLG Diagnostic Structure Restauration Chapelle St Joseph.pdf
# 00 - GENERALITES COMMUNES.pdf
# Page de garde.pdf
# Cahier des plantations type_Evran-Quartier de La Jânée.pdf
# Carnet de détail-Evran-Quartier de La Jânée.pdf
# 20211210  INSTRUCTION Levage de tourets de cables V5_FR_Signé XP_MV.pdf
# Charte Santé Sécurité et Environnement - 2023 07 01.pdf
# FR - Guide Blindage - 2023-A4.pdf
# FR - Guide Levage - 2023 - A5.pdf
# GHSD-GOV-FORM-0051_VQS_FR_V00.pdf
# GHSD-GOV-FORM-0052_Causerie H&S_FR_V00.pdf
# Incontournables de la sécurité.pdf
# Outil DEFI Chantier- Fiche émargement.pdf
# Outil DEFI Chantier- Fiche prestataire à communiquer en amont.pdf
# Outil DEFI Chantier- Fiche résumée.pdf
# Standard RQS-2023.pdf
# Annexe 2 -  Descritption du projet travaux réseaux 2025.pdf
# 20211210  INSTRUCTION Levage de tourets de cables V5_FR_Signé XP_MV.pdf
# Charte Santé Sécurité et Environnement - 2023 07 01.pdf
# FR - Guide Blindage - 2023-A4.pdf
# FR - Guide Levage - 2023 - A5.pdf
# GHSD-GOV-FORM-0051_VQS_FR_V00.pdf
# GHSD-GOV-FORM-0052_Causerie H&S_FR_V00.pdf
# Incontournables de la sécurité.pdf
# Outil DEFI Chantier- Fiche émargement.pdf
# Outil DEFI Chantier- Fiche prestataire à communiquer en amont.pdf
# Outil DEFI Chantier- Fiche résumée.pdf
# Standard RQS-2023.pdf
# Annexe 2 -  Descritption du projet travaux réseaux 2025.pdf
# 20211210  INSTRUCTION Levage de tourets de cables V5_FR_Signé XP_MV.pdf
# Charte Santé Sécurité et Environnement - 2023 07 01.pdf
# FR - Guide Blindage - 2023-A4.pdf
# FR - Guide Levage - 2023 - A5.pdf
# GHSD-GOV-FORM-0051_VQS_FR_V00.pdf
# GHSD-GOV-FORM-0052_Causerie H&S_FR_V00.pdf
# Incontournables de la sécurité.pdf
# Outil DEFI Chantier- Fiche émargement.pdf
# Outil DEFI Chantier- Fiche prestataire à communiquer en amont.pdf
# Outil DEFI Chantier- Fiche résumée.pdf
# Standard RQS-2023.pdf
# Annexe 2 -  Descritption du projet travaux réseaux 2025.pdf
# 20211210  INSTRUCTION Levage de tourets de cables V5_FR_Signé XP_MV.pdf
# Charte Santé Sécurité et Environnement - 2023 07 01.pdf
# FR - Guide Blindage - 2023-A4.pdf
# FR - Guide Levage - 2023 - A5.pdf
# GHSD-GOV-FORM-0051_VQS_FR_V00.pdf
# GHSD-GOV-FORM-0052_Causerie H&S_FR_V00.pdf
# Incontournables de la sécurité.pdf
# Outil DEFI Chantier- Fiche émargement.pdf
# Outil DEFI Chantier- Fiche prestataire à communiquer en amont.pdf
# Outil DEFI Chantier- Fiche résumée.pdf
# Standard RQS-2023.pdf
# Annexe 2 -  Descritption du projet travaux réseaux 2025.pdf
# En'RnoV - Contrat type SPS et HSE ind2.pdf
# 20211210  INSTRUCTION Levage de tourets de cables V5_FR_Signé XP_MV.pdf
# Charte Santé Sécurité et Environnement - 2023 07 01.pdf
# FR - Guide Blindage - 2023-A4.pdf
# FR - Guide Levage - 2023 - A5.pdf
# GHSD-GOV-FORM-0051_VQS_FR_V00.pdf
# GHSD-GOV-FORM-0052_Causerie H&S_FR_V00.pdf
# Incontournables de la sécurité.pdf
# Outil DEFI Chantier- Fiche émargement.pdf
# Outil DEFI Chantier- Fiche prestataire à communiquer en amont.pdf
# Outil DEFI Chantier- Fiche résumée.pdf
# Standard RQS-2023.pdf
# 5.3 - Guide application i-topo.pdf
# STG Réseau preisolé - 08072024 - indice J.3.pdf
# 22_04_11_RMG_7all_rochester_Amiante.pdf
# 22_04_11_RMG_7all_rochester_Plomb.pdf
# 22_04_11_RMG_9all_rochester_Amiante.pdf
# 22_04_11_RMG_9all_rochester_Plomb.pdf
# 22_04_11_RMG_Rue_Dunant_Bat_LaPoste_plomb.pdf
# 23_08_30_RMG_Appenti_rue_Dr_Aussant_Amiante.pdf
# 24_03_20_RMG_Rue_Dunant_Bat_LaPoste_Amiante.pdf
# Calendrier_previsionnel.pdf
# Plan_localisation_travaux_ extrait_AVP_ADIngé.pdf
# 21 12 13  Accord de confidentialité VIERGES.pdf
# BPU.pdf
# Attestation_visite.pdf
# 2019.09.13 AO fiche de renseignements - SPS.pdf
# 2019.09.16 MDC E dde proposition honoraires.pdf
# Cargill Field Safety Guide French (fr_FR)_DIGITAL_CROPPED.pdf
# Cargill Field Safety Guide French (fr_FR)_DIGITAL_CROPPED.pdf
# EIR0183 - ESQ02 - Dossier complet - 2023.10.06.pdf
# EIR0183 - ESQ02 - Dossier complet - 2023.10.06.pdf
# ATAE Devis SPS D230855 Ombrières QUELAINES ST GAULT.pdf
# DossierPC_MO-0003_Quelaines.pdf
# pour envoie ATAE.pdf
# 2253-AVP-AMG-S3-A    CHAUCIDOU  rue louison BOBET.pdf
# MS_SPS_4_Cadre Memoire technique.pdf
# SPS Annexe .pdf
# 02-AE-SPS_cat2 et 3.pdf
# Annexe-1-2024_Organisation_Alimentation.pdf
# Convocation-a-reunion-de-chantier-n1.pdf
# Convocation-a-reunion-preparatoire-de-chantier--.pdf
# demande_devis_EGUIMOS_6002934_23127823.pdf
# PV-AG-2024-12-27.pdf
# DEVIS 22439520.pdf
# PRO_Phase-II_2024_06_28.pdf
# 24L178E - 2024.06.05 - 01ESQ - SCI Batisur - LDa.pdf
# 24L178E - 2024.06.05 - 01ESQ - SCI Batisur - LDa.pdf
# 08230089_AMOE DALKIA_Centrale biomasse_ESQ_TVB_D.pdf
# 08230089_AMOE DALKIA_Centrale biomasse_ESQ_TVB_D.pdf
# Descriptif technique de l'installation.pdf
# Descriptif technique de l'installation.pdf
# PFD Créhen avec options_rev G.pdf
# PFD Créhen avec options_rev G.pdf
# 2023.07.26 - PC - A3.pdf
# 2023.07.26 - PC - A3.pdf
# 03_AE.pdf
# 05_DPGF_SPS_EchangeurRN176RD366 .pdf
# EXEMPLE_LIVRABLE_DIUO.pdf
# EXEMPLE_LIVRABLE_PGC.pdf
# EXEMPLE_LIVRABLE_RJ.pdf
# MEMOIRE_JUSTIFICATIF_ET_EXPLICATIF.pdf
# ESQUISSE 10112023.pdf
# DPGF avenant 1.pdf
# FMS  PPSPS - Cancale .pdf
# Tableau rectificatif suite ABF travaux sans souci.pdf
# Tableau rectificatif suite ABF travaux sans souci.pdf
# SYSIV-004_Aaltimmo2 - Dossier PC_compressed.pdf
# DESCRIPTIF - 4 rue de la Gardelle 35400 SAINT MALO.pdf
# Principe echafaudage.pdf
# PV chantier n° 2.pdf
# Rapport_ 4 rue de la Gardelle_002S6002611.pdf
# CGA - PI - 15 000 euros.pdf
# CGA - PI - 15 000 euros.pdf
# DDT_-_24-WTH-12043__Direction_du_Patrimoine.pdf
# Locaux DRH_Hôtel de ville_Bat Nord_Projet.pdf
# annexe 2 DAAD 93 avenue de Marville 1.pdf
# annexe 2 DAAD 93 avenue de Marville 1.pdf
# annexe 3 DAAD Ex LEMEE.pdf
# annexe 3 DAAD Ex LEMEE.pdf
# annexe 4 DAAD Ex ECOBICHON 1.pdf
# annexe 4 DAAD Ex ECOBICHON 1.pdf
# FICHE PROJET_REMPART 22-26 Phase I.pdf
# Aménagement d'un plateau de bureaux - CESAME.PDF
# Coûts estimatifs du projet - calendrier.pdf
# Méthodologie ANGERS CESAME plateaux bureaux.pdf
# SPS_Cadre de décomposition par phase.pdf
# 00a_memoire technique.pdf
# PRO_V1_Planches_Strates_oa.pdf
# PRO_V1_Strates-oa.pdf
# Memoire technique OA.pdf
# 095_CAM_ESQ_indB_scenario1.pdf
# APD MAM PLUMIEUX.pdf
# PiècesGraphiques-PC2-Opticien-EspaceBourienne-CARENTOIR-19.02.24.pdf
# AAGV-PLOERMEL_DAO-Amenagt_02.pdf
# AAGV-PLOERMEL_DAO-Masse_02.pdf
# AAGV-PLOERMEL_DAO-Reseaux_02.pdf
# CLPT_pole agroalimentaire_Nov 2015.pdf
# CSPS_PRESENTATION PROJET.pdf
# Etude de programmation nov 2024.pdf
# RDC_AC_CSPS_PLI_Phase1_vcr.pdf
# JDE-AB_PRO_Liste_pieces_.pdf
# 31_JDE‐AB_A_Notice estimation des travaux par secteurs.pdf
# 32_JDE-AB_A_Notice_hydraulique_nivellement_reseau.pdf
# 33_JDE-AB_A_Notice d'éclairage et étude photométrique.pdf
# 101_JDE-AB_A_PLN_existant_et_périmètre_projet_avec_secteurs.pdf
# 102_JDE-AB_A_PLN_des_domanialités_futures.pdf
# 103_JDE-AB_A_PLN_masse_général.pdf
# 104_JDE-AB_A_PLN_superposition_existant_projet.pdf
# 202_JDE-AB_A_PLN_de_sols_et_mobilier.pdf
# 203_JDE-AB_A_PLN_de_borduration_et_ouvrages.pdf
# 204_JDE-AB_A_PLN_de_plantations.pdf
# 301_JDE-2_B_Plan_de_synthese_des_réseaux_projetés_et_conservés.pdf
# 302_JDE-2_A_Plan_de_dépose_abandon_des_reseaux_existants.pdf
# 303_JDE-2_B_Plan_d'assainissement.pdf
# 304_JDE-2_B_Plan_du_reseau_ICE_ECL_et_RT_Projetes.pdf
# 305_JDE-2_A_PLN_des_terrassements_déblais_remblais.pdf
# 306_JDE_A_PLN_de_sols_fertiles.pdf
# 501_A_Carnet_de_details_techniques.pdf
# 502_A_Carnet_de_détails_Plantations.pdf
# Questions-Reponses-07102021.pdf
# 0-Manu-Liste pièces DIAG-ESQ.pdf
# PdG.pdf
# 1000015-Rehabilitation Manu-1er étage.pdf
# 1000015-Rehabilitation Manu-2e étage.pdf
# 1000015-Rehabilitation Manu-3e étage.pdf
# 1000015-Rehabilitation Manu-Mezzanine.pdf
# 1000015-Rehabilitation Manu-Rdc.pdf
# 1000015-Rehabilitation Manu-Ssol.pdf
# 1000015-Rehabilitation Manu-Toiture.pdf
# PROGRAMME REHABILITATION MANUFACTURE-1.pdf
# PDG APS.pdf
# 11-Niveau rdc.pdf
# 12-Niveau Mezza.pdf
# 13-Niveau 1.pdf
# 14-Niveau 2.pdf
# 15-Niveau 3.pdf
# Annexe Diag Finitions - Numérotations locaux.pdf
# 80-DIAG-ELEC-Synoptique-HT-BT-Existant.pdf
# 90 Site Existant & Réseaux.pdf
# 4-Tableau des surfaces.pdf
# 5-Notice technique TCE.pdf
# 6-Notice environnementale.pdf
# 9-Notice financière.pdf
# 1.1-DIAG_PAT.pdf
# 1.2-DIAG Structure MANU.pdf
# 1.3-DIAG CVC PS.pdf
# 1.4-DIAG ELEC.pdf
# 1.5 - DIAG ASC - Second Oeuvre - Finitions.pdf
# 1.6-DIAG VRD-AE.pdf
# 1.7-DIAG ACOUSTIQUE MANU_GAMBA.pdf
# 1.8-diag SSI Manu.pdf
# MANU - SUPPORT ATELIER 1 - 210526.pdf
# MANU_MoM - CR ATELIER 1+ ATELIER 2  - BATI - 210609.pdf
# MANU_MoM - CR ATELIER 1+ ATELIER 2 - DGTPDS - 210609.pdf
# Annexe_01_Liste contributeurs BIM_V1.pdf
# Annexe_02_Listes des sous-projets_V1.pdf
# Annexe_03_Fiche Avis BIM_V1.pdf
# MTN_Convention_BIM_Conception_V1.pdf
# 21-1161-ATAE.pdf
# Commande Publique Solidaire - Guide methodologique - Edition 2022.pdf
# BOT_CORDON BOISE_PLN_LIM PRO EST_500.pdf
# 203_BOT_CBE_A_NOT_notice_générale_aménagement.pdf
# 600_BOT_CBE_A_PLN_masse_général_PAT.pdf
# 601_BOT_CBE_A_PLN_masse_général_NOB.pdf
# AXIOM-plan-projet-05-04-2022.pdf
# notice dc1.pdf
# notice-dc2-2019.pdf
# notice-dc4-2019.pdf
# LC_SPS_Cassantin FXD.pdf
# LC-SPS_Cassantin FXD.pdf
# AVP ESPACES PUBLICS.pdf
# PRESENTATION PROGRAMME.pdf
# 1 -Synoptique HTA projection 2025 - Chantier remplacement des postes satellites.pdf
# 2 -Synoptique HTA projection 2025 et 2027 (NHT).pdf
# 3 -TPBTNSYN01_HT01- Synoptique HTA.pdf
# CHU37_TROUSSEAU MASSE implantation base vie.pdf
# 2022_01_17__EP Chronovelo_BEEP_Diagnostic_V1.pdf
# 2022_01_17_Annexe1_Diag sequences_zone_agglomeree.pdf
# 2022_01_17_Annexe2_Diag sequences_zone metropolitaine.pdf
# Atlas - connexion Aigne-Milesse-Saturnin.pdf
# Atlas - connexion Arnage-Ruaudin.pdf
# Atlas - connexion Coulaines-Sarge-Yvre.pdf
# Atlas - connexion Coulaines-Yvre.pdf
# Atlas - connexion Fay-Mans.pdf
# Atlas - connexion Milesse-Chapelle-Mans.pdf
# Atlas - connexion Mulsanne-Arnage.pdf
# Atlas - connexion Mulsanne-Ruaudin.pdf
# Atlas - connexion SaintGeorgesBois-Allonnes.pdf
# Atlas - connexion Trange-ArmatureRouge.pdf
# Atlas - connexion Trange-PruilleChetif-Rouillon-Mans.pdf
# Atlas - ligne bleue.pdf
# Atlas - ligne jaune.pdf
# Atlas - ligne marron.pdf
# Atlas - ligne rouge.pdf
# Atlas - maillage Centre.pdf
# Atlas - maillage Est.pdf
# Atlas - maillage Nord.pdf
# Atlas - maillage Ouest.pdf
# Atlas - maillage Sud-Ouest.pdf
# Atlas - maillage Sud.pdf
# LMC_PLN_connnexions_ind.B_220919.pdf
# LMC_PLN_armature bleue_ind.B_220919.pdf
# LMC_PLN_armature jaune_ind.B_220919.pdf
# LMC_PLN_armature marron_ind.B_220919.pdf
# LMC_PLN_armature rouge_ind.B_220919.pdf
# BEEP_Notice EP Chronovelo_V2_19sept2022.pdf
# ALL_GSPL_COMPTES RENDUS PRO.pdf
# ALL_GSPL_TABLEAU REEMPLOI PRO.pdf
# ALL_GSPL_TABLEAU SURFACES PRO.pdf
# ALL_GSPL_AMENAGEMENT INT  PRO.pdf
# ALL_GSPL_CARNET DE PERSPECTIVES PRO.pdf
# ALL_GSPL_CARNET MEUBLES PRO.pdf
# ALL_GSPL_DETAILS PRO.pdf
# ALL_GSPL_NOMENCLATURE MINT PRO.pdf
# ALL_GSPL_NOMENCLATURE PANNEAUX EXTENSION PRO.pdf
# bon de commande diagnostic amiante.pdf
# PA4_B.pdf
# PA8.1Programme des travaux IndB.pdf
# PA8.2_B.pdf
# PA8.3_B.pdf
# 220511_PC.pdf
# estimatif 220511.pdf
# 1-Note de synthèse.pdf
# 3-Insertions.pdf
# 1-Note de synthèse.pdf
# 3-Insertions.pdf
# 21-4 AE.pdf
# 21-4 Descriptif sommaire.pdf
# Doc2.pdf
# Doc4.pdf
# cahier des charges CSPS_V2.pdf
# 2023_02_28_NoticeAVP_QSNT4.pdf
# 2021_12_06_présentation_projet_raphael_elize.pdf
# A3 PHASE 1 _v3 fouilles et PAV.pdf
# PGC_entretien_voirie_OA_terrains_3.pdf
# 211 - Cahier des charges prestations intellectuelles_SPS + CT.pdf
# Plan.pdf
# 0169-1b-Programme-UFR Sciences-LeMans.pdf
# MEMOIRE _JUSTIFICATIF.pdf
# NOTE_EXPLICATIVE.pdf
# Physique_Chimie Façades.pdf
# MANS-Physique_Chimie-R0-1 Affectation.pdf
# MANS-Physique_Chimie-R00-PN-A-A0 + 1 pli 1-100 Affectation.pdf
# MANS-Physique_Chimie-R01-PN-A-A0 + 1 pli 1-100 Affectation.pdf
# MANS-Physique_Chimie-R02-PN-A-A0 + 1 pli 1-100 Affectation.pdf
# MANS-Physique_Chimie-R03-PN-A-A0 + 1 pli 1-100 Affectation.pdf
# MANS-Physique_Chimie-R04-PN-A-A0 + 1 pli 1-100 Affectation.pdf
# Projet Parking Souligné 23012023.pdf
# Tours 2022-2023_Situation des ouvrages.pdf
# Dossier APD.pdf
# RAAT Résidence des Jardins.pdf
# DossierPC-VersionDef_LMS-060_Challes.pdf
# descriptif mission SPS bât 075 CHP.pdf
# Chiffres validés charpente couvert bardage Mancelle.pdf
# cadre de prix.pdf
# 2 . AC à BDC Fondettes CSPS vu DME_GH.pdf
# DossierPC-VersionDef_LMS-062_GrandLuce.pdf
# 57 Lombron - Cahier des charges prestations intellectuelles.pdf
# 103 - Cahier des charges prestations intellectuelles_SPS + CT.pdf
# 3.pdf
# 4.pdf
# 5A.pdf
# 5B.pdf
# 6.pdf
# 7.pdf
# 8.pdf
# DOEEL01.pdf
# DOEEL02.pdf
# DOEEL03.pdf
# DOEPLOMB01.pdf
# DOEPLOMB02.pdf
# DOEPLOMB03.pdf
# DOERES01.pdf
# DOEVMC01.pdf
# DOEVMC02.pdf
# DOEVMC03.pdf
# Fusion C80 N03.pdf
# Fusion C80 N03.pdf
# Fusion C80 N04.pdf
# Fusion C80 N04.pdf
# Fusion C80 N05.pdf
# Fusion C80 N05.pdf
# DossierPC-VersionDef_LMS-0047_Mahonias.pdf
# DEVIS_DEGRE_CSPS_BECS.pdf
# Devis ATAE D230371  Opération Conteneurs Enterres Ph 2 Le Mans Rue Bossuet.pdf
# Devis ATAE D230371  Opération Conteneurs Enterres Ph 2 Le Mans Rue Bossuet.pdf
# Devis ATAE D230371  Opération Conteneurs Enterres Ph 2 Le Mans Rue Bossuet.pdf
# Devis ATAE D230371  Opération Conteneurs Enterres Ph 2 Le Mans Rue Bossuet.pdf
# Localisation terrasse 31 rue du Nord Le Mans.pdf
# Mode opératoire - MOP_003.pdf
# 22-9 AE.pdf
# 22-9 Descriptif sommaire.pdf
# DossierPC_SYS-069_ImprimerieTF.pdf
# 2210 Calendrier prévisionnel d'exécution.pdf
# 23-4 AE.pdf
# 23-4 Descriptif sommaire.pdf
# 370261029V_0112_AMT_DTA_20221214_PRS_B.pdf
# CSPS-bat112-emplacement travaux.pdf
# 370261029V_0067_N_00_Futur2.pdf
# 64 Trangé - Cahier des charges prestations intellectuelles.pdf
# Masse_2.pdf
# Masse.pdf
# T2.pdf
# T3 T4 T5.pdf
# SPS-CARNAC.pdf
# CahierdeschargesManeErGroez.pdf
# Plancadastre.pdf
# 163724403944kp3szu7rsb_21S0112-NONRETENUSPSCARNAC-ATAE.pdf
# LC_7149_signée.pdf
# Programme de l_operation_Blue Dock.pdf
# OEA 2 - Signer ou Cosigner un document.pdf
# Règles de nommage.pdf
# 24S0237-PAPOURSPS-ResidenceAutonomieJOSSELIN.pdf
# AVISAUXCANDIDATS.pdf
# AVISAUXCANDIDATS.pdf
# AVISAUXCANDIDATS.pdf
# Programme Square Morbihan.pdf
# LC_7528_signée.pdf
# 2021.208-SPS CHAPLIN-ATAE.pdf
# declaHonneur.pdf
# 2. WBT_BUREAUX SONADEV_CSPS_PROGRAMME.pdf
# 2.1 WBT_BUREAUX SONADEV_ANNEXE 1_PROGRAMME_SPATIALISATION R+2.pdf
# 2.2 WBT_BUREAUX SONADEV_ANNEXE 2_PROGRAMME_SPATIALISATION R+3.pdf
# 44 - St Nazaire - boulodrome - Permis de démolir.pdf
# Mode operatoire dépoussièrage plomb Amiante Services-1-1.pdf
# 00_PRESENTATION GLOBALE_J BART_2024 - Copie-1-1.pdf
# Cadre memoire technique O409RD complété.pdf
# UGECAM~1.PDF
# UGECAM~1.PDF
# UGECAM~2.PDF
# UGECAM~2.PDF
# 1 - ETAT ACTUEL ORL.PDF
# 2 - PROJET ORL.PDF
# Fiche synthese MSub014 CSPS.pdf
# Comment repondre par voie dematerialisee sur cette plate-forme.pdf
# note de présentation.pdf
# AE-SPS.pdf
# Annexe 2 - GSRD PTD.pdf
# ATAE CSPS DEVIS DIVATTE SUR LOIRE RESTRUCTURATION ET EXTENSION GS ROBERT DOISNEAU.pdf
# Comment repondre par voie dematerialisee sur cette plate-forme.pdf
# fichier_questionreponse (1).pdf
# 2022.10.12_FAISA_HAUTE GOULAINE.pdf
# RD748_PR30+500-31+500.pdf
# 2 Extrait cadastral.pdf
# 6 Photos.pdf
# 7 Photos.pdf
# 8 Photos.pdf
# Notice descriptive chateau Etenduère mission SPS.pdf
# 08. Estimatif des travaux.pdf
# 13D02811-note de présentation CSPS.pdf
# ATAE CSPS  RPDL Lycée Europe Robert Schuman.pdf
# Livre1-REFERENTIEL SOBRIETE_V2_05-nov-19.pdf
# PR Cugand_Implantation V4-PR CUGAND.pdf
# Accord ATAE.pdf

# %%
#df_consult_ebp[df_consult_ebp['file_name'] == "PA-SPSLORIENT.pdf"]
df_consult_ebp[df_consult_ebp['file_name'].str.strip() == "PA-SPSLORIENT.pdf"]
# Out:
#                                SPS Name    Ville Entreprise  \
# 106919  Nicolas POTIER - Nicolas POTIER  LORIENT         MH
#
#                                    Mission statut_consult  \
# 106919  Construction immeuble 20 logements          Devis
#
#                                                 file_path        ID EBP  \
# 106919  C:\Users\jch_m\ATAE\Nicolas POTIER - Nicolas P...  no EBP 17307
#
#                 file_name  AO_docs        AO_doc_type
# 106919  PA-SPSLORIENT.pdf     True  Procedure Adaptee

# %%
df_consult_ebp['AO_docs'].value_counts()
# Out:
# AO_docs
# False    152162
# True       3095
# Name: count, dtype: int64

# %%
df_consult_ebp['AO_doc_type'].value_counts()
# Out:
# AO_doc_type
# no type              153673
# CCTP                    709
# RC                      457
# CCAP                    200
# Planning                 92
# Lettre Consult           85
# AAPC                     30
# Procedure Adaptee        11
# Name: count, dtype: int64

# %%
df_consult_ebp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155257 entries, 0 to 155256
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SPS Name        155257 non-null  object
#  1   Ville           155257 non-null  object
#  2   Entreprise      155257 non-null  object
#  3   Mission         155257 non-null  object
#  4   statut_consult  155257 non-null  object
#  5   file_path       155257 non-null  object
#  6   ID EBP          155257 non-null  object
#  7   file_name       155257 non-null  object
#  8   AO_docs         155257 non-null  bool
#  9   AO_doc_type     155257 non-null  object
# dtypes: bool(1), object(9)
# memory usage: 10.8+ MB

# %%
TableReport(df_consult_ebp)
# Out:
# Processing column  10 / 10
# <TableReport: use .open() to display>

# %%
# Creation d'un DF_consult_elevated avec une ligne par "EBP ID", 
# et l'ajout des features resultants de l'extraction 

df_consult_ao = df_consult_ebp[df_consult_ebp['AO_docs']==True]
df_consult_elevated = df_consult_ao.drop_duplicates(subset=["ID EBP"], keep="first")

# Suppression des colonnes desormais inutiles
df_consult_elevated = df_consult_elevated.drop(columns=['file_path','file_name','AO_docs','AO_doc_type'])

df_consult_elevated['lieu'] = ""
df_consult_elevated['type travaux'] = ""
df_consult_elevated['planning'] = ""
df_consult_elevated['duree travaux'] = 0
df_consult_elevated['prix travaux'] = 0.0
df_consult_elevated['maitre ouvrage'] = ""
df_consult_elevated['maitre oeuvre'] = ""

# %%
df_consult_elevated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 923 entries, 0 to 155112
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SPS Name        923 non-null    object
#  1   Ville           923 non-null    object
#  2   Entreprise      923 non-null    object
#  3   Mission         923 non-null    object
#  4   statut_consult  923 non-null    object
#  5   ID EBP          923 non-null    object
#  6   lieu            923 non-null    object
#  7   type travaux    923 non-null    object
#  8   planning        923 non-null    object
#  9   duree travaux   923 non-null    int64
#  10  prix travaux    923 non-null    float64
#  11  maitre ouvrage  923 non-null    object
#  12  maitre oeuvre   923 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 101.0+ KB

# %% [markdown]
# # Test de modeles pour resumer et extraire l'info un CCTP

# %%
prompt_role = "tu es un assistant pour analyser les appels d'offres, extraire les informations demandees en suivant les instructions"

prompt_task_resumer = "En Francais, extrait du texte les elements suivants : \n\
   'Nom Chantier': scope du projet, objet du chantier ;\n\
   'Lieu du Chantier': ville, Commune, Departement, Rue ; \n\
   'Maitre ouvrage': nom du Maitre d'ouvrage du projet ;\n\
   'Maitre oeuvre': nom du maitre d'oeuvre du chantier  ;\n\
   'Type de travaux': type et nature du travaux du chantier exemple: amenagement, construction ;\n \
   'Planning previsionnel': dates du chantier par lot, par phase ;\n\
   'Prix des travaux (en euros)': exemple <10_000> ;\n\
   'Duree Previsionnelle des Travaux (en mois)': exemple <8> ;\n\
   'Categorie operation SPS':  I, II, ou III ;\n\
Réponds en respectant la structure ci-dessus \n\
Donne uniquement les informations disponibles dans le texte , sans interpretation ou estimation. \n\
Donne des reponses chiffrées et quantifiées lorsque c'est possible. \n\
Ne mentionne pas **Autres informations:**  \n\
La reponse doit avoir un maximum 900 mots \n \
Texte: "

prompt_task_json = "En Francais, Formate les informations extraites et dans le texte, avec une structure JSON, en respectant strictement les clefs et types specifies tels que \n \
{ \
  \"Nom Chantier\": \"<string>\", \
  \"Lieu du Chantier\": \"<string>\",\
  \"Maitre ouvrage\": \"<string>\", \
  \"Maitre oeuvre\": \"<string>\", \
  \"Type de Travaux\": \"<string>\", \
  \"Planning previsionnel\": \"<string>\", \
  \"Prix des travaux (en euros)\": \"<integer>\" , \
  \"Durée Prévisionnelle des Travaux (en mois)\": \"<integer>\" ,\
} \n\
Donne des reponses uniquement pour ces clefs. en chiffre lorsque c'est possible. Si pas d'info, laisser vide  \n "

# %%
# Init Ollama, with list of model, prompt

ollama_url = "http://localhost:11434"

# Get an ollama client
llmclient = Client(host=ollama_url)

model_options = {
    "num_predict": 1300,  # max number of tokens to predict
    "temperature": 0.1,
    "top_p": 0.9,
}


# 'mistral-small3.1=14G  llama3.2:latest=2G gemma3:4b=3.3G
#list_model = ["gemma3:4b", "llama3.2", "minicpm-v", "mistral-small3.1"]
list_model = ["gemma3:12b", "gemma2:9b", "llama3.1:8b", "mistral:7b"]

# %%
## Run all models for the same task (prompt + file) for comparison
##

def run_list_model():

    # Loop on the list of models specified
    for i in range(len(list_model)):
        model_name = list_model[i]
        print("\n==========================================")
        print(f"===== Test model :{i+1}/{len(list_model)}: {model_name} =========\n")
        
        #Resumer
        prompt_full = prompt_task_resumer + "".join(text)
        result = llmclient.generate( model=model_name, prompt=prompt_full, options=model_options, system=prompt_role)
        #pprint(result, compact=True, sort_dicts=False)
        bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s \n" + result["response"])

        #JSON
        prompt_full = prompt_task_json + "".join(result["response"])
        result = llmclient.generate( model=model_name, prompt=prompt_full, options=model_options)
        #pprint(result, compact=True, sort_dicts=False)
        bid_utils.print_text_wrapped(f"\nLLM response pour JSON: in {result['total_duration']/10**9:.0f}s")

        bid_utils.print_json_info_cctp(result["response"])


def run_list_model_chat(text_from_file):
    for i in range(len(list_model)):
        model_name = list_model[i]
        print("\n==========================================")
        print(f"===== Test model :{i+1}/{len(list_model)}: {model_name} =========\n")
        
        #Init system:
        result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'system','content': prompt_role}])

        #Resumer
        prompt_full = prompt_task_resumer + "".join(text_from_file)
        #result = llmclient.generate(model=model_name, prompt=prompt_full, options=model_options, system=prompt_role)
        result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content': prompt_full}])
  
        pprint(result, compact=True, sort_dicts=False)
        #bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s \n" + result["response"])
        bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s \n" + result.message.content)

        #JSON
        #prompt_full = prompt_task_json + "".join(result["response"])
        #prompt_full = prompt_task_json + "".join(result.message.content)
        prompt_full = prompt_task_json + "".join(result.message.content)
        #result = llmclient.generate( model=model_name, prompt=prompt_full, options=model_options)
        result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full}])
                                                                                    
        #pprint(result, compact=True, sort_dicts=False)
        bid_utils.print_text_wrapped(f"\nLLM response pour JSON: in {result['total_duration']/10**9:.0f}s")

        bid_utils.print_json_info_cctp(result.message.content)

# %%
## Liste all files for given consultation
## Consolide les fichiers bruts ou les resumés
## Run le modele pour resumer et json

# Preferable de faire une extraction par type de fichier (CCTP, CCAP, ..) avec un prompt dédié.
# donc regroupement par type de fichier

def run_1model_nCCTP_proj(model_name="gemma2:9b", nb_of_projet_to_test = 1):
    #model_name = "gemma2:9b"
    #nb_of_projet_to_test = 5
    count_id = 1

    # liste des ID correspondants au mask
    condition_mask = (df_consult_ebp['AO_docs'] == True) & \
                        (df_consult_ebp['AO_doc_type'] == "CCTP") 

    matching_ebp_ids = df_consult_ebp.loc[condition_mask, 'ID EBP'].unique()
    print(f"il y a {len(matching_ebp_ids)} projets avec au moins 1 document du type CCTP")
    print(f"on teste l'extraction avec {nb_of_projet_to_test} projets, par le modele {model_name}\n")

    #Init system:
    result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'system','content': prompt_role}])

    if len(matching_ebp_ids) > 0:
        # Determine how many unique IDs we can actually select (min of 5 or available count)
        num_to_select = min(nb_of_projet_to_test, len(matching_ebp_ids))

        # Randomly select the desired number of unique EBP IDs
        selected_ebp_ids = np.random.choice(matching_ebp_ids, num_to_select, replace=False)

        #print(f"\n{num_to_select} ID(s) EBP aléatoire(s) sélectionné(s) correspondant au filtre:")
        for ebp_id in selected_ebp_ids:

            filtered_row = df_consult_ebp[df_consult_ebp['ID EBP'] == ebp_id].iloc[0]
            print(f"\n{count_id}/{nb_of_projet_to_test} => ID:{ebp_id} statut_consult: {filtered_row['statut_consult']}")

            text_multi_files = ""
            list_file_consult = df_consult_ebp[(df_consult_ebp['ID EBP'] == ebp_id) & (df_consult_ebp['AO_doc_type'] == 'CCTP')]['file_path']
            print(f"Il y a {len(list_file_consult)} fichiers dans la dossier AO consultation pour ce projet {ebp_id}")
            print(f"Ville:{filtered_row['Ville']}  Entreprise:{filtered_row['Entreprise']}  Mission:{filtered_row['Mission']}")
            for file_path in list_file_consult:
                nb_segment = file_path.split("\\")
                print("==> ", nb_segment[-1].strip())
                text_file = bid_utils.loadpdf_as_text(file_path.strip())
                text_multi_files += text_file + "\n" # Contatenate text
                
            if text_multi_files != "":
                print("Run model pour les fichier(s) selectionné(s)")

                #Resumer
                #prompt_full = prompt_task_resumer + "".join(text_multi_files)
                prompt_full = prompt_task_resumer + text_multi_files
                #result = llmclient.generate( model=model_name, prompt=prompt_full, options=model_options)
                result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full}])
                #pprint(result, compact=True, sort_dicts=False)
                bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s \n")

                #JSON
                #prompt_full = prompt_task_json + "".join(result["response"])
                #result = llmclient.generate( model=model_name, prompt=prompt_full, options=model_options)
                #prompt_full = prompt_task_json + "".join(result.message.content)
                prompt_full = prompt_task_json + result.message.content
                result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full}])
                #pprint(result, compact=True, sort_dicts=False)
                bid_utils.print_text_wrapped(f"\nLLM response pour JSON: in {result['total_duration']/10**9:.0f}s \n")

                cctp_json = bid_utils.print_json_info_cctp(result.message.content)
                
                # extrait les infos du JSON
                if cctp_json != "":
                    parsed_json = {} # Initialize an empty dictionary
                    try:
                        parsed_json = json.loads(cctp_json)
                    except json.JSONDecodeError as e:
                        print(f"Error decoding JSON string: {e}")
                    except TypeError:
                        print("Input is not a string.") 
                    
                    # Extrait chaque clef
                    lieu_value = parsed_json.get("Lieu du Chantier")
                    type_travaux_value = parsed_json.get("Type de Travaux")
                    planning_value = parsed_json.get("Planning previsionnel")
                    duree_travaux_value = parsed_json.get("Durée Prévisionnelle des Travaux (en mois)")
                    prix_travaux_value = parsed_json.get("Prix des travaux (en euros)")
                    moa_value = parsed_json.get("Maitre ouvrage")
                    moe_value = parsed_json.get("Maitre oeuvre")

                    # Mise à jour du df_consult_elevated
                    mask = df_consult_elevated['ID EBP'] == ebp_id
                    if lieu_value is not None:
                        df_consult_elevated.loc[mask, 'lieu'] = lieu_value
                    if type_travaux_value is not None:
                        df_consult_elevated.loc[mask, 'type travaux'] = type_travaux_value
                    if duree_travaux_value is not None:
                        df_consult_elevated.loc[mask, 'duree travaux'] = duree_travaux_value
                    if planning_value is not None:
                        df_consult_elevated.loc[mask, 'planning'] = planning_value
                    if prix_travaux_value is not None:
                        df_consult_elevated.loc[mask, 'prix travaux'] = prix_travaux_value
                    if moa_value is not None:
                        df_consult_elevated.loc[mask, 'maitre ouvrage'] = moa_value
                    if moe_value is not None:
                        df_consult_elevated.loc[mask, 'maitre oeuvre'] = moe_value
            else:
                print("Pas de fichiers consult à processer")
            count_id += 1
    else:
        print("\nAucune ligne trouvée avec 'statut_consult' == 'Chantiers'")

# %%
## Teste les modeles 

#list_model = ["gemma3:12b", "gemma2:9b", "llama3.1:8b", "mistral:7b"]
# gemma3:12b : very long , not performing so well.
# mistral:7b : does not respect instructions (info request, JSON structure)
list_model = ["llama3.1:8b", "gemma2:9b"]

# Select 1 file for the test
condition_mask = (df_consult_ebp['AO_docs'] == True) & \
                    (df_consult_ebp['AO_doc_type'] == "CCTP") 

matching_ebp_ids = df_consult_ebp.loc[condition_mask, 'ID EBP'].unique()
print(f"il y a {len(matching_ebp_ids)} projets avec au moins 1 document du type CCTP")
if len(matching_ebp_ids) > 0:
    # Determine how many unique IDs we can actually select (min of 5 or available count)
    #num_to_select = min(1, len(matching_ebp_ids))
    selected_ebp_id = np.random.choice(matching_ebp_ids, 1, replace=False)
    filtered_row = df_consult_ebp[df_consult_ebp['ID EBP'] == selected_ebp_id[0]].iloc[0]
    print(f"ID:{selected_ebp_id} statut_consult: {filtered_row['statut_consult']}")
    print(f"Ville:{filtered_row['Ville']}  Entreprise:{filtered_row['Entreprise']}  Mission:{filtered_row['Mission']}")
    
    text_multi_files = ""
    file_consult = df_consult_ebp[(df_consult_ebp['ID EBP'] == selected_ebp_id[0]) & (df_consult_ebp['AO_doc_type'] == 'CCTP')]['file_path'].iloc[0]
    print("File ==> ", file_consult)
    text_to_analyse = bid_utils.loadpdf_as_text(file_consult.strip())

# Compare model results for same file same prompt , models to test is defined in list_model
run_list_model_chat(text_to_analyse)   #best model so far: llama3.1:8b
# Out:
# il y a 350 projets avec au moins 1 document du type CCTP
# ID:['no EBP 3731'] statut_consult: Devis
# Ville:BREM SUR MER  Entreprise:ELAUCAMACLE 5  Mission:LE CHAMP PRIEUR
# File ==>  C:\Users\jch_m\ATAE\Fabien ROUILLE - FABIEN\00-DEVIS\ARCHIVE DEVIS\DEVIS 2023\BREM SUR MER - ELAUCAMACLE 5 - LE CHAMP PRIEUR\Consultation\S4978 PA - LE CHAMP PRIEUR v3 2023.04.17-DCE EA.pdf
#
#
# ==========================================
# ===== Test model :1/2: llama3.1:8b =========
#
# ChatResponse(model='llama3.1:8b', created_at='2025-06-09T20:31:15.5078834Z', done=True, done_reason='stop', total_duration=61811867300, load_duration=12926100, prompt_eval_count=1307, prompt_eval_duration=36702490500, eval_count=269, eval_duration=25095418700, message=Message(role='assistant', content='Voici les éléments extraits du texte en respectant la structure demandée :\n\n**Nom Chantier**\n* Projet de la SAS ELAUCAMACLE 5\n* Lotissement "LE CHAMP PRIEUR"\n\n**Lieu du Chantier**\n* Ville : BREM-SUR-MER\n* Commune : BREM-SUR-MER\n* Département : inconnu (mais mentionné comme étant dans la région RGF 93 - CC47)\n* Rue : Rue du Champ Prieur\n\n**Maitre ouvrage**\n* Nom du Maitre d\'ouvrage : SAS ELAUCAMACLE 5\n\n**Maitre oeuvre**\n* Nom du maitre d\'oeuvre : THOUZEAU Vincent, Géomètre-Expert\n\n**Type de travaux**\n* Travaux divers (aménagement, construction, démolition, etc.)\n\n**Planning previsionnel**\n* Dates non spécifiées dans le texte\n\n**Prix des travaux (en euros)**\n* Inconnu\n\n**Duree Previsionnelle des Travaux (en mois)**\n* Inconnue\n\n**Categorie operation SPS**\n* I, II ou III : inconnu', thinking=None, images=None, tool_calls=None))
#
# LLM response pour resumer: in 62s
# Voici les éléments extraits du texte en respectant la structure demandée :
#
# **Nom Chantier**
# * Projet de la SAS ELAUCAMACLE 5
# * Lotissement "LE CHAMP PRIEUR"
#
# **Lieu du Chantier**
# * Ville : BREM-SUR-MER
# * Commune : BREM-SUR-MER
# * Département : inconnu (mais mentionné comme étant dans la région RGF 93 - CC47)
# * Rue : Rue du Champ Prieur
#
# **Maitre ouvrage**
# * Nom du Maitre d'ouvrage : SAS ELAUCAMACLE 5
#
# **Maitre oeuvre**
# * Nom du maitre d'oeuvre : THOUZEAU Vincent, Géomètre-Expert
#
# **Type de travaux**
# * Travaux divers (aménagement, construction, démolition, etc.)
#
# **Planning previsionnel**
# * Dates non spécifiées dans le texte
#
# **Prix des travaux (en euros)**
# * Inconnu
#
# **Duree Previsionnelle des Travaux (en mois)**
# * Inconnue
#
# **Categorie operation SPS**
# * I, II ou III : inconnu
#
# LLM response pour JSON: in 37s
#
# Accès aux données extraites :
# Nom Chantier: Projet de la SAS ELAUCAMACLE 5 - Lotissement "LE CHAMP PRIEUR"
# Lieu du Chantier: {'Ville': 'BREM-SUR-MER', 'Commune': 'BREM-SUR-MER', 'Département': '', 'Rue': 'Rue du Champ Prieur'}
# Maitre ouvrage: SAS ELAUCAMACLE 5
# Maitre oeuvre: THOUZEAU Vincent, Géomètre-Expert
# Type de Travaux: Travaux divers (aménagement, construction, démolition, etc.)
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois):
# Prix des travaux (en euros):
# Categorie operation SPS:
#
# ==========================================
# ===== Test model :2/2: gemma2:9b =========
#
# ChatResponse(model='gemma2:9b', created_at='2025-06-09T20:33:07.4629491Z', done=True, done_reason='stop', total_duration=56360856800, load_duration=19543700, prompt_eval_count=1350, prompt_eval_duration=36088107100, eval_count=172, eval_duration=20252144700, message=Message(role='assistant', content='**Nom Chantier**:  Lotissement "LE CHAMP PRIEUR"  \n\n**Lieu du Chantier**: \n* Ville: BREM-SUR-MER\n* Commune: BREM-SUR-MER\n* Departement: 85440 TALMONT SAINT HILAIRE\n\n**Maitre ouvrage**: SAS ELAUCAMACLE 5\n\n**Maitre oeuvre**:  THOUZEAU Vincent, Géomètre-Expert \n\n**Type de travaux**:  aménagement, construction (démolition, terrassement, empierrement, pose de clôture)\n\n**Planning previsionnel**:  Non disponible.\n\n**Prix des travaux (en euros)**: Non disponible.\n\n**Duree Previsionnelle des Travaux (en mois)**: Non disponible.\n\n**Categorie operation SPS**: Non disponible. \n', thinking=None, images=None, tool_calls=None))
#
# LLM response pour resumer: in 56s
# **Nom Chantier**:  Lotissement "LE CHAMP PRIEUR"
#
# **Lieu du Chantier**:
# * Ville: BREM-SUR-MER
# * Commune: BREM-SUR-MER
# * Departement: 85440 TALMONT SAINT HILAIRE
#
# **Maitre ouvrage**: SAS ELAUCAMACLE 5
#
# **Maitre oeuvre**:  THOUZEAU Vincent, Géomètre-Expert
#
# **Type de travaux**:  aménagement, construction (démolition, terrassement, empierrement,
# pose de clôture)
#
# **Planning previsionnel**:  Non disponible.
#
# **Prix des travaux (en euros)**: Non disponible.
#
# **Duree Previsionnelle des Travaux (en mois)**: Non disponible.
#
# **Categorie operation SPS**: Non disponible.
#
#
# LLM response pour JSON: in 25s
#
# Accès aux données extraites :
# Nom Chantier: Lotissement "LE CHAMP PRIEUR"
# Lieu du Chantier: BREM-SUR-MER
# Maitre ouvrage: SAS ELAUCAMACLE 5
# Maitre oeuvre: THOUZEAU Vincent, Géomètre-Expert
# Type de Travaux: aménagement, construction (démolition, terrassement, empierrement, pose de clôture)
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois):
# Prix des travaux (en euros):
# Categorie operation SPS: Information non disponible

# %%
run_1model_nCCTP_proj(model_name="llama3.1:8b", nb_of_projet_to_test = 10)
# Out:
# il y a 350 projets avec au moins 1 document du type CCTP
# on teste l'extraction avec 10 projets, par le modele llama3.1:8b
#
#
# 1/10 => ID:no EBP 14217 statut_consult: Devis
# Il y a 2 fichiers dans la dossier AO consultation pour ce projet no EBP 14217
# Ville:TOURS  Entreprise:USID  Mission:HOTEL DU GD Commandement
# ==>  CCTP_SPIE_SIGNE_AUBANEL.pdf
# ==>  CCTP_TPPL_SIGNE_AUBANEL.pdf
# Run model pour les fichier(s) selectionné(s)
#
# LLM response pour resumer: in 151s
#
#
# LLM response pour JSON: in 77s
#
#
# Accès aux données extraites :
# Nom Chantier:
# Lieu du Chantier: Base de Défense de Tours
# Maitre ouvrage:
# Maitre oeuvre:
# Type de Travaux: Modernisation, adaptation et rénovation de bâtiments
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois):
# Prix des travaux (en euros):
# Categorie operation SPS: Information non disponible
#
# 2/10 => ID:210395 statut_consult: Archive
# Il y a 2 fichiers dans la dossier AO consultation pour ce projet 210395
# Ville:RSY  Entreprise:VENDEE EAU  Mission:Réservoirs sur tour ZI NORD
# ==>  1 DCE CSPS_230321.pdf
# ==>  1 DCE CSPS_230321.pdf
# Run model pour les fichier(s) selectionné(s)
#
# LLM response pour resumer: in 160s
#
#
# LLM response pour JSON: in 45s
#
#
# Accès aux données extraites :
# Nom Chantier:
# Lieu du Chantier:
# Maitre ouvrage:
# Maitre oeuvre:
# Type de Travaux: Construction d'une station d'eau
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois):
# Prix des travaux (en euros):
# Categorie operation SPS: Information non disponible
#
# 3/10 => ID:no EBP 22116 statut_consult: Perdu
# Il y a 1 fichiers dans la dossier AO consultation pour ce projet no EBP 22116
# Ville:GUERANDE  Entreprise:CAP ATLANTIQUE  Mission:KERHILIERS
# ==>  25CAP0017CFM_CCTP_SPS PA Villejames-Kerhilliers.pdf
# Run model pour les fichier(s) selectionné(s)
#
# LLM response pour resumer: in 150s
#
#
# LLM response pour JSON: in 34s
#
#
# Accès aux données extraites :
# Nom Chantier: Requalification de la rue et place Kerhilliers
# Lieu du Chantier: Parc d'activités de Villejames
# Maitre ouvrage:
# Maitre oeuvre:
# Type de Travaux: Requalification de voirie
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois):
# Prix des travaux (en euros):
# Categorie operation SPS: Information non disponible
#
# 4/10 => ID:no EBP 17210 statut_consult: Devis
# Il y a 1 fichiers dans la dossier AO consultation pour ce projet no EBP 17210
# Ville:MONTERBLANC ET TREDION  Entreprise:MH  Mission:RÉHABILITATION ÉNERGÉTIQUE
# ==>  ACSPS-CCP.pdf
# Run model pour les fichier(s) selectionné(s)
#
# LLM response pour resumer: in 167s
#
#
# LLM response pour JSON: in 45s
#
#
# Accès aux données extraites :
# Nom Chantier:
# Lieu du Chantier:
# Maitre ouvrage:
# Maitre oeuvre:
# Type de Travaux:
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois):
# Prix des travaux (en euros):
# Categorie operation SPS: Information non disponible
#
# 5/10 => ID:250101 statut_consult: Chantier
# Il y a 1 fichiers dans la dossier AO consultation pour ce projet 250101
# Ville:LORIENT  Entreprise:MH  Mission:Construction immeuble 50 Logts Maison Santé Stationnement
# ==>  24S0296-SPS-CCTP.pdf
# Run model pour les fichier(s) selectionné(s)
#
# LLM response pour resumer: in 169s
#
#
# LLM response pour JSON: in 52s
#
#
# Accès aux données extraites :
# Nom Chantier:
# Lieu du Chantier:
# Maitre ouvrage:
# Maitre oeuvre:
# Type de Travaux: Construction
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois): 0
# Prix des travaux (en euros): 0
# Categorie operation SPS: Information non disponible
#
# 6/10 => ID:no EBP 610 statut_consult: Devis
# Il y a 1 fichiers dans la dossier AO consultation pour ce projet no EBP 610
# Ville:CHALLANS  Entreprise:SCCV BATICANA (LOTIPROMO)  Mission:Clémenceau 4 MI
# ==>  CCTP GENERALITES.pdf
# Run model pour les fichier(s) selectionné(s)
#
# LLM response pour resumer: in 185s
#
#
# LLM response pour JSON: in 52s
#
#
# Accès aux données extraites :
# Nom Chantier:
# Lieu du Chantier:
# Maitre ouvrage:
# Maitre oeuvre:
# Type de Travaux: Construction
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois): 0
# Prix des travaux (en euros): 0
# Categorie operation SPS: Information non disponible
#
# 7/10 => ID:220127 statut_consult: Archive
# Il y a 1 fichiers dans la dossier AO consultation pour ce projet 220127
# Ville:RSY  Entreprise:PC DE VENDEE  Mission:Extension bâtiment
# ==>  395-PROTECTION CIVILE-PRO-CCTP.pdf
# Run model pour les fichier(s) selectionné(s)
#
# LLM response pour resumer: in 178s
#
#
# LLM response pour JSON: in 49s
#
#
# Accès aux données extraites :
# Nom Chantier:
# Lieu du Chantier:
# Maitre ouvrage:
# Maitre oeuvre:
# Type de Travaux: Réhabilitation d'un bâtiment
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois):
# Prix des travaux (en euros):
# Categorie operation SPS: Information non disponible
#
# 8/10 => ID:220468 statut_consult: Archive
# Il y a 1 fichiers dans la dossier AO consultation pour ce projet 220468
# Ville:BARBATRE  Entreprise:MAIRIE  Mission:Cimetière paysager La Martinière
# ==>  2022.05.06 - Cimetière Le Martinière - CCTP.pdf
# Run model pour les fichier(s) selectionné(s)
#
# LLM response pour resumer: in 153s
#
#
# LLM response pour JSON: in 45s
#
#
# Accès aux données extraites :
# Nom Chantier:
# Lieu du Chantier:
# Maitre ouvrage:
# Maitre oeuvre:
# Type de Travaux: Voirie, réseaux et aménagements
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois):
# Prix des travaux (en euros):
# Categorie operation SPS: Information non disponible
#
# 9/10 => ID:no EBP 14070 statut_consult: Perdu
# Il y a 1 fichiers dans la dossier AO consultation pour ce projet no EBP 14070
# Ville:NANTES  Entreprise:SEMITAN Accord cadre 21SEB2310  Mission:2ème offre
# ==>  A3-CCTP-AC SPS-SE v5.pdf
# Run model pour les fichier(s) selectionné(s)
#
# LLM response pour resumer: in 161s
#
#
# LLM response pour JSON: in 36s
#
#
# Accès aux données extraites :
# Nom Chantier:
# Lieu du Chantier:
# Maitre ouvrage: SEMITAN (Société d'Exploitation des Matériaux et Infrastructures du Territoire de Nantes Métropole)
# Maitre oeuvre: Titulaire du marché
# Type de Travaux:
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois):
# Prix des travaux (en euros):
# Categorie operation SPS: Information non disponible
#
# 10/10 => ID:no EBP 14171 statut_consult: Perdu
# Il y a 2 fichiers dans la dossier AO consultation pour ce projet no EBP 14171
# Ville:TOURS  Entreprise:CHRU TOURS  Mission:Nouvel Hôpital Psychiatrique
# ==>  10_2022-122_NHP_CCTP_CSPS.pdf
# ==>  9_2022-122_NHP_CCTP_ CT.pdf
# Run model pour les fichier(s) selectionné(s)
#
# LLM response pour resumer: in 165s
#
#
# LLM response pour JSON: in 81s
#
#
# Accès aux données extraites :
# Nom Chantier:
# Lieu du Chantier:
# Maitre ouvrage:
# Maitre oeuvre:
# Type de Travaux: Prestations intellectuelles
# Planning previsionnel:
# Durée Prévisionnelle des Travaux (en mois):
# Prix des travaux (en euros):
# Categorie operation SPS: Information non disponible

# %%
len(df_consult_elevated[df_consult_elevated['type travaux'] != ''])
df_consult_elevated[df_consult_elevated['type travaux'] != ''].head(10)
# Out:
#                                SPS Name     Ville                 Entreprise  \
# 2988                Eric Garnier - ERIC  CHALLANS  SCCV BATICANA (LOTIPROMO)
# 5233                Eric Garnier - ERIC  BARBATRE                     MAIRIE
# 23708           Fabien ROUILLE - FABIEN       RSY               PC DE VENDEE
# 23838           Fabien ROUILLE - FABIEN       RSY                 VENDEE EAU
# 86767     Nicolas PATRY - NICOLAS PATRY     TOURS                 CHRU TOURS
# 86998     Nicolas PATRY - NICOLAS PATRY     TOURS                       USID
# 107225  Nicolas POTIER - Nicolas POTIER   LORIENT                         MH
# 142468    Stéphanie LAFORGE - STEPHANIE  GUERANDE             CAP ATLANTIQUE
#
#                                                   Mission statut_consult  \
# 2988                                      Clémenceau 4 MI          Devis
# 5233                     Cimetière paysager La Martinière        Archive
# 23708                                  Extension bâtiment        Archive
# 23838                         Réservoirs sur tour ZI NORD        Archive
# 86767                        Nouvel Hôpital Psychiatrique          Perdu
# 86998                            HOTEL DU GD Commandement          Devis
# 107225  Construction immeuble 50 Logts Maison Santé St...       Chantier
# 142468                                         KERHILIERS          Perdu
#
#               ID EBP                            lieu  \
# 2988      no EBP 610
# 5233          220468
# 23708         220127
# 23838         210395
# 86767   no EBP 14171
# 86998   no EBP 14217        Base de Défense de Tours
# 107225        250101
# 142468  no EBP 22116  Parc d'activités de Villejames
#
#                                              type travaux planning  \
# 2988                                         Construction
# 5233                      Voirie, réseaux et aménagements
# 23708                        Réhabilitation d'un bâtiment
# 23838                    Construction d'une station d'eau
# 86767                         Prestations intellectuelles
# 86998   Modernisation, adaptation et rénovation de bât...
# 107225                                       Construction
# 142468                          Requalification de voirie
#
#        duree travaux prix travaux maitre ouvrage maitre oeuvre
# 2988               0            0
# 5233
# 23708
# 23838
# 86767
# 86998
# 107225             0            0
# 142468
