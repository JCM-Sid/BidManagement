# %%
import pandas as pd
import numpy as np
import os
import warnings
import time
import re

import json

from skrub import TableReport
from ollama import Client
from pdfquery import PDFQuery
from pprint import pprint
from IPython.display import display, HTML, Markdown

import bid_utils

#!pip install -U -q "google-genai>=1.0.0"
from google import  genai
#from google.colab import userdata
# Out:
# c:\DocPerso\Dev_Python\ProjetsPerso\BidManagement\bid_utils.py:222: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search(r"\d+", str(duree_travaux_value))
# c:\DocPerso\Dev_Python\ProjetsPerso\BidManagement\bid_utils.py:238: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search(r"\d+", str(prix_travaux_value))

# %% [markdown]
# # Preparation des données (dataframe) pour automatiser l'extraction des informations

# %%
## load the dfs built in 1_collect_files
rep_drive_ATAE =  r"C:\Users\jch_m\ATAE"
rep_data_input =  r"C:\Users\jch_m\ATAE\Nicolas MONCEAU - NICOLAS\Stage_AppelsOffres\data_input"
rep_data_output = r"C:\Users\jch_m\ATAE\Nicolas MONCEAU - NICOLAS\Stage_AppelsOffres\data_output"

path_df_EBP = os.path.join(rep_data_output, "df_EBP.pkl")
df_EBP = pd.read_pickle(path_df_EBP)

path_df_consult = os.path.join(rep_data_output, "df_consult.pkl")
df_consult = pd.read_pickle(path_df_consult)

path_df_rejet = os.path.join(rep_data_output, "df_rejet.pkl")
df_rejet = pd.read_pickle(path_df_rejet)

# preparation du path pour le fichier resultat 
path_df_consult_elevated = os.path.join(rep_data_output, "df_consult_elevated.pkl")

# %%
# Merge df_consult and df_EBP pour sync EBP ID on the mission/files
# note: no need to sync EBP with rejet, because none of the Rejet file match an EBP entry (dans la liste des repertoires et fichiers). normal ?

# Define the columns to match on
match_columns = ['SPS Name', 'Ville', 'Entreprise', 'Mission']

df_consult_ebp = pd.merge(df_consult, df_EBP, on=match_columns, how='left', suffixes=('_consult', '_ebp'))
df_consult_ebp['ID EBP'] = df_consult_ebp['ID EBP_ebp'].fillna("no EBP")
df_consult_ebp = df_consult_ebp.drop(columns=['ID EBP_ebp','ID EBP_consult', 'statut_ebp'])

#df_consult_ebp['file_name'] = df_consult_ebp['file_path'].str.split(r'\\').str[-1].strip()
df_consult_ebp['file_name'] = df_consult_ebp['file_path'].str.split(r'\\').str[-1].str.strip()

# %%
# define a unique 'no EBP xx'  for each combinaison of SPS+Ville+Entreprise+Mission, for all related files
#
mask = df_consult_ebp["ID EBP"] == "no EBP"

# Create the combined series only for the masked rows
combined_series_for_update = (
    df_consult_ebp.loc[mask, 'SPS Name'].astype(str) + '_' +
    df_consult_ebp.loc[mask, 'Ville'].astype(str) + '_' +
    df_consult_ebp.loc[mask, 'Entreprise'].astype(str) + '_' +
    df_consult_ebp.loc[mask, 'Mission'].astype(str)
)

# Generate unique IDs for this series
unique_ids, _ = pd.factorize(combined_series_for_update)

# Assign back to the original DataFrame using the mask
df_consult_ebp.loc[mask, "ID EBP"] = "no EBP " + (unique_ids + 1).astype(str)

# %%
# Add columns "AO_docs" (True/False), "AO_Doc_type"(CCTP, CCAP, RC, AAPC, Memo_tech), "Commande"(True/False)

# Set AO_doc_type
# Initialize all with default value
df_consult_ebp['AO_doc_type'] = 'no type'

# Define mask for inclusion et exclusion 
df_consult_ebp['AO_docs'] = (
    (df_consult_ebp['file_path'].str.lower().str.contains('devis') & df_consult_ebp['file_path'].str.lower().str.contains(r'\\consul')) | 
    (df_consult_ebp['file_path'].str.lower().str.contains(r'\\adm') & df_consult_ebp['file_path'].str.lower().str.contains(r'\\consul'))
)
mask = df_consult_ebp['AO_docs'] == True

# Création d'un masque d'exclusion : lot est retiré provisoirement
mots_cles_a_exclure = ["plan ", "assurance", "honneur", "plans", "coupe", "vue", "facade", "archi"] 
exclusion_mask = df_consult_ebp.loc[mask, 'file_path'].str.lower().apply(
    lambda x: any(mot in x for mot in mots_cles_a_exclure)
)

# Sélection des lignes à inclure (qui ne contiennent pas les mots-clés à exclure)
inclusion_mask = mask.copy()
inclusion_mask.loc[mask] = ~exclusion_mask

# par ordre inverse d'importance, pour que les derniers checks ecrasent eventuellement les premiers
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('sps', case=False, na=False), 'AO_doc_type'] = 'CCTP'
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('PA-', case=False, na=False), 'AO_doc_type'] = 'Procedure Adaptee'
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('RC', case=False, na=False), 'AO_doc_type'] = 'Reglement'
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('lettre', case=False, na=False), 'AO_doc_type'] = 'Lettre Consult'
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('courier', case=False, na=False), 'AO_doc_type'] = 'Lettre Consult'
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('consult', case=False, na=False), 'AO_doc_type'] = 'Lettre Consult'
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('AAPC', case=False, na=False), 'AO_doc_type'] = 'AAPC' #Achat avec concurence
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('glement', case=False, na=False), 'AO_doc_type'] = 'Reglement'
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('planning', case=False, na=False), 'AO_doc_type'] = 'Planning'
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('phasag', case=False, na=False), 'AO_doc_type'] = 'Planning'
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('programme', case=False, na=False), 'AO_doc_type'] = 'CCTP' # Technique
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('CCTP', case=False, na=False),'AO_doc_type'] = 'CCTP' # Technique
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('CCP', case=False, na=False), 'AO_doc_type'] = 'CCP' # General , Technique et Admin
df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('CCAP', case=False, na=False), 'AO_doc_type'] = 'CCAP' #Administratif
#df_consult_ebp.loc[inclusion_mask & df_consult_ebp['file_name'].str.contains('DCE', case=False, na=False), 'AO_doc_type'] = 'CCTP' # Dossier Consult

# %%
print("nb total de fichiers:",len(df_consult_ebp['AO_doc_type']))
print("nb total de fichiers de consultation:",len(df_consult_ebp[df_consult_ebp['AO_docs']==True] ))
print("nb de fichiers AO_docs avec un type identifié:",len(df_consult_ebp['AO_doc_type']) - len(df_consult_ebp[df_consult_ebp['AO_doc_type']=='no type']))
print("\nDétails par type", df_consult_ebp['AO_doc_type'].value_counts())
# Out:
# nb total de fichiers: 158545
# nb total de fichiers de consultation: 3106
# nb de fichiers AO_docs avec un type identifié: 829
#
# Détails par type AO_doc_type
# no type              157716
# CCTP                    345
# Reglement               244
# CCAP                    181
# AAPC                     28
# Lettre Consult           12
# Planning                  9
# Procedure Adaptee         7
# CCP                       3
# Name: count, dtype: int64

# %%
# Liste de fichiers de consultations sans type clairement identifié (ou volontairement exclus)
#
list_file_AO_notype = ""
mask2 = (df_consult_ebp['AO_docs'] == True) &  (df_consult_ebp['AO_doc_type'] == 'no type')
list_file_AO_notype = [df_consult_ebp.loc[mask2, 'file_name'], df_consult_ebp.loc[mask2, 'file_path']]
for index, row in df_consult_ebp.loc[mask2, ['file_name', 'file_path']].iterrows():
    file = row['file_name']
    file_path = row['file_path'].strip()

    if any(mot in file.lower() for mot in mots_cles_a_exclure):
        pass

    bid_utils.path_to_link(file_path)
# Out:
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/00_PLAN TOPO.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\00_PLAN TOPO.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/01_PLAN DE MASSE INITIAL.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\01_PLAN DE MASSE INITIAL.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/02_PLAN RDC + R1 INITIAL SALLE JOEL DUBOIS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\02_PLAN RDC + R1 INITIAL SALLE JOEL DUBOIS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/03_PLAN DE TOITURE INITIAL SALLE JOEL DUBOIS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\03_PLAN DE TOITURE INITIAL SALLE JOEL DUBOIS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/04_COUPES INITIALES SALLE JOEL DUBOIS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\04_COUPES INITIALES SALLE JOEL DUBOIS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/05_FACADES INITIALES SALLE JOEL DUBOIS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\05_FACADES INITIALES SALLE JOEL DUBOIS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/06_PLAN RDC INITIAL COSEC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\06_PLAN RDC INITIAL COSEC.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/07_PLAN DE TOITURE INITIAL COSEC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\07_PLAN DE TOITURE INITIAL COSEC.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/08_COUPES INITIALES COSEC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\08_COUPES INITIALES COSEC.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/09_FACADES INITIALES COSEC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\09_FACADES INITIALES COSEC.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/10_PLAN DES RESEAUX INITIAL.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\10_PLAN DES RESEAUX INITIAL.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/11_PLAN DE MASSE PROJET.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\11_PLAN DE MASSE PROJET.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/12_PLAN RDC + R1 PROJET SALLE JOEL DUBOIS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\12_PLAN RDC + R1 PROJET SALLE JOEL DUBOIS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/13_PLAN DE TOITURE PROJET SALLE JOEL DUBOIS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\13_PLAN DE TOITURE PROJET SALLE JOEL DUBOIS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/14_COUPES PROJETEES SALLE JOEL DUBOIS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\14_COUPES PROJETEES SALLE JOEL DUBOIS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/15_COUPES PROJETEES SALLE JOEL DUBOIS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\15_COUPES PROJETEES SALLE JOEL DUBOIS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/16_FACADES PROJETEES SALLE JOEL DUBOIS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\16_FACADES PROJETEES SALLE JOEL DUBOIS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/17_PLAN RDC PROJET COSEC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\17_PLAN RDC PROJET COSEC.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/18_PLAN DE TOITURE PROJET COSEC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\18_PLAN DE TOITURE PROJET COSEC.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/19_COUPES PROJETEES COSEC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\19_COUPES PROJETEES COSEC.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/20_FACADES PROJETEES COSEC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\20_FACADES PROJETEES COSEC.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/PLANS ARCHITECTE/21_PLAN DES RESEAUX PROJET.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\PLANS ARCHITECTE\21_PLAN DES RESEAUX PROJET.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2024/ST HERBLAIN - VLOK - Réhab Bat industriel en AGENCE V-LOK/Consult/24-02-07-Notice Archi et Tech ESQ compris esti.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2024\ST HERBLAIN - VLOK - Réhab Bat industriel en AGENCE V-LOK\Consult\24-02-07-Notice Archi et Tech ESQ compris esti.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/TRIGNAC - CENTRALITES 44 - Aménagmt MAM/ADMINISTRATIF/Consult/NOE_DCE_DOSSIER DCE_Carnet de plans archi.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\TRIGNAC - CENTRALITES 44 - Aménagmt MAM\ADMINISTRATIF\Consult\NOE_DCE_DOSSIER DCE_Carnet de plans archi.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/1_Lettre_consultation_SPS2023.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\1_Lettre_consultation_SPS2023.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/2.1_ AE_SPS2023_LOT01_PPI ete 2023.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\2.1_ AE_SPS2023_LOT01_PPI ete 2023.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/2.2_ AE_SPS2023_LOT02_Conformite Douet.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\2.2_ AE_SPS2023_LOT02_Conformite Douet.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/2.3_ AE_SPS2023_LOT03_Ascenseur Med.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\2.3_ AE_SPS2023_LOT03_Ascenseur Med.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/2.4_ AE_SPS2023_LOT04_Chauffage ALSH.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\2.4_ AE_SPS2023_LOT04_Chauffage ALSH.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/2.5_ AE_SPS2023_LOT05_Mod ecole Douet.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\2.5_ AE_SPS2023_LOT05_Mod ecole Douet.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/2.6_ AE_SPS2023_LOT06_Remplacement luminaires.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\2.6_ AE_SPS2023_LOT06_Remplacement luminaires.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/2.7_ AE_SPS2023_LOT07_Mod stade R Masse.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\2.7_ AE_SPS2023_LOT07_Mod stade R Masse.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/2.8_ AE_SPS2023_LOT08_Eclairage gym Prof.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\2.8_ AE_SPS2023_LOT08_Eclairage gym Prof.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/2.9_ AE_SPS2023_LOT09_Eclairage terrain R Masse.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\2.9_ AE_SPS2023_LOT09_Eclairage terrain R Masse.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/ST SEB - MAIRIE - luminaires bâts municipaux/ADMINISTRATIF/Consultation/Règlement de consultation-1.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\ST SEB - MAIRIE - luminaires bâts municipaux\ADMINISTRATIF\Consultation\Règlement de consultation-1.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/VERTOU - SCI de l'ALLIER - Bat LCJ CAPTEURS/ADM/Consult/Plan 01 - Masse RDC Coupes Facades - LCJ CAPTEURS Vertou.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\VERTOU - SCI de l'ALLIER - Bat LCJ CAPTEURS\ADM\Consult\Plan 01 - Masse RDC Coupes Facades - LCJ CAPTEURS Vertou.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2024/VERTOU - SCI de l'ALLIER - Bat LCJ CAPTEURS/ADM/Consult/Plan 01 - Masse RDC Coupes Facades - LCJ CAPTEURS Vertou.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2024\VERTOU - SCI de l'ALLIER - Bat LCJ CAPTEURS\ADM\Consult\Plan 01 - Masse RDC Coupes Facades - LCJ CAPTEURS Vertou.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2025/PELLERIN - DEPT44 - Collège P&M Curie Modulaires 4 classes/ADMINISTRATIF/Consultation/Estimation ESQ-DIAG Modulaire Pierre et Marie Curie.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2025\PELLERIN - DEPT44 - Collège P&M Curie Modulaires 4 classes\ADMINISTRATIF\Consultation\Estimation ESQ-DIAG Modulaire Pierre et Marie Curie.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2025/ST NAZAIRE - NANTES UNIV - Projet filière Heinlex/ADMINISTRATIF/Consultation/CSPS Contexte_Filières_HLX.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2025\ST NAZAIRE - NANTES UNIV - Projet filière Heinlex\ADMINISTRATIF\Consultation\CSPS Contexte_Filières_HLX.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2025/ST NAZAIRE - NANTES UNIV - Projet filière Heinlex/ADMINISTRATIF/Consultation/Heinlex Filieres-Programme-rev2.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2025\ST NAZAIRE - NANTES UNIV - Projet filière Heinlex\ADMINISTRATIF\Consultation\Heinlex Filieres-Programme-rev2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/04-ARCHIVES/ARCHIVES 2025/ST NAZAIRE - NANTES UNIV - Projet filière Heinlex/ADMINISTRATIF/Consultation/PLANNING UNIV_230926.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\04-ARCHIVES\ARCHIVES 2025\ST NAZAIRE - NANTES UNIV - Projet filière Heinlex\ADMINISTRATIF\Consultation\PLANNING UNIV_230926.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/000 PLANS D'ENSEMBLE/ARC - 101 Plan de situation.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\000 PLANS D'ENSEMBLE\ARC - 101 Plan de situation.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/000 PLANS D'ENSEMBLE/ARC - 102 Plan Masse.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\000 PLANS D'ENSEMBLE\ARC - 102 Plan Masse.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/100 PLANS DE NIVEAUX/ARC - 101 Plan R-1.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\100 PLANS DE NIVEAUX\ARC - 101 Plan R-1.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/100 PLANS DE NIVEAUX/ARC - 102 Plan RDC.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\100 PLANS DE NIVEAUX\ARC - 102 Plan RDC.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/100 PLANS DE NIVEAUX/ARC - 103 Plan R+1.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\100 PLANS DE NIVEAUX\ARC - 103 Plan R+1.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/100 PLANS DE NIVEAUX/ARC - 104 Plan de toiture.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\100 PLANS DE NIVEAUX\ARC - 104 Plan de toiture.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/200 COUPES/ARC - 201 Coupes 50.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\200 COUPES\ARC - 201 Coupes 50.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/200 COUPES/ARC - 202 Coupes 50 - 20.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\200 COUPES\ARC - 202 Coupes 50 - 20.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/200 COUPES/ARC - 203 Coupes 20.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\200 COUPES\ARC - 203 Coupes 20.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/300 ELEVATIONS/ARC - 301 Façades LONGITUDINALES.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\300 ELEVATIONS\ARC - 301 Façades LONGITUDINALES.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/300 ELEVATIONS/ARC - 302 Façades TRANSVERSALES.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\300 ELEVATIONS\ARC - 302 Façades TRANSVERSALES.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/300 ELEVATIONS/ARC - 303 Façades LOCAL VELOS.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\300 ELEVATIONS\ARC - 303 Façades LOCAL VELOS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/400 CARNET DES DETAILS/ARC - 401  Carnet de détails intérieurs.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\400 CARNET DES DETAILS\ARC - 401  Carnet de détails intérieurs.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/400 CARNET DES DETAILS/ARC - 402 Carnet de détail paysage.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\400 CARNET DES DETAILS\ARC - 402 Carnet de détail paysage.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/600 PERSPECTIVES/ARC - 601 Perspective extérieure.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\600 PERSPECTIVES\ARC - 601 Perspective extérieure.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/600 PERSPECTIVES/ARC - 602 Perspective intérieure.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\600 PERSPECTIVES\ARC - 602 Perspective intérieure.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/800 NOMENCLATURES/ARC - 801 Nomenclature des menuiseries extérieures.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\800 NOMENCLATURES\ARC - 801 Nomenclature des menuiseries extérieures.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/800 NOMENCLATURES/ARC - 802 Nomenclature des menuiseries intérieures.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\800 NOMENCLATURES\ARC - 802 Nomenclature des menuiseries intérieures.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/800 NOMENCLATURES/ARC - 803 Repérage des doublages et cloisons.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\800 NOMENCLATURES\ARC - 803 Repérage des doublages et cloisons.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/01 - pièces architecturales/900 SURFACES/ARC - 900 SURFACES.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\01 - pièces architecturales\900 SURFACES\ARC - 900 SURFACES.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/MONTAIGU VENDEE - TERRES DE MONTAIGU - Réaménagement du Parc Henri Joyau/Consultation/Plan de situation Trx parc Henri Joyau.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\MONTAIGU VENDEE - TERRES DE MONTAIGU - Réaménagement du Parc Henri Joyau\Consultation\Plan de situation Trx parc Henri Joyau.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2023/BARRE DE MONTS - M. ROUSSEAU DUMARCET - Lot le St Michel/Consult/22062-PA8b-2023-06-22.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2023\BARRE DE MONTS - M. ROUSSEAU DUMARCET - Lot le St Michel\Consult\22062-PA8b-2023-06-22.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2023/LUCS SUR BOULOGNE - DEPT85 -  Historial Chaufferie Bois (attntion cde existante C190152)/Consultation/LUCS SUR BOULOGNE-APD-Notice technique LOTS ARCHITECTURAUX-Ind0.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2023\LUCS SUR BOULOGNE - DEPT85 -  Historial Chaufferie Bois (attntion cde existante C190152)\Consultation\LUCS SUR BOULOGNE-APD-Notice technique LOTS ARCHITECTURAUX-Ind0.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2023/LUCS SUR BOULOGNE - DEPT85 -  Historial Chaufferie Bois (attntion cde existante C190152)/Consultation/NOTICE DESCRIPTIVE ESTIMATIVE ARCHI.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2023\LUCS SUR BOULOGNE - DEPT85 -  Historial Chaufferie Bois (attntion cde existante C190152)\Consultation\NOTICE DESCRIPTIVE ESTIMATIVE ARCHI.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2024/00- NON RETENU/MACHECOUL - PODELIHA - Construction 30 logements LA PLANTIVE/Consult/Pièces du dossier/plan cadastral parcelle AT117.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2024\00- NON RETENU\MACHECOUL - PODELIHA - Construction 30 logements LA PLANTIVE\Consult\Pièces du dossier\plan cadastral parcelle AT117.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2024/ST JEAN DE MONTS - SCI BMC - Extension commerce/Consult/2023-12-12-A1_existant.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2024\ST JEAN DE MONTS - SCI BMC - Extension commerce\Consult\2023-12-12-A1_existant.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2024/ST JEAN DE MONTS - SCI BMC - Extension commerce/Consult/2023-12-12-A1_projet.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2024\ST JEAN DE MONTS - SCI BMC - Extension commerce\Consult\2023-12-12-A1_projet.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/03-EN ATTENTE PHASE 2/APREMONT - VIABILIS - LA SOURCE/ADM/Consultation/M22.054-CR01-20230907.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\03-EN ATTENTE PHASE 2\APREMONT - VIABILIS - LA SOURCE\ADM\Consultation\M22.054-CR01-20230907.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/03-EN ATTENTE PHASE 2/APREMONT - VIABILIS - LA SOURCE/ADM/Consultation/M22054-21-voirie.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\03-EN ATTENTE PHASE 2\APREMONT - VIABILIS - LA SOURCE\ADM\Consultation\M22054-21-voirie.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/04-EN COURS/BEAUVOIR SUR MER - SCI PICCA  (BONNIN - SATOV) - Micro-crèche/ADM/Consult/20231027_Bonnin_M04485_Archi 2B.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\04-EN COURS\BEAUVOIR SUR MER - SCI PICCA  (BONNIN - SATOV) - Micro-crèche\ADM\Consult\20231027_Bonnin_M04485_Archi 2B.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/04-EN COURS/ST JEAN DE MONTS - SCCV - LA Parée Verte/ADM/Consult/DCE  2024-06-17/PLANS ARCHITECTE/01 PLANS MASSE 20240617.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\04-EN COURS\ST JEAN DE MONTS - SCCV - LA Parée Verte\ADM\Consult\DCE  2024-06-17\PLANS ARCHITECTE\01 PLANS MASSE 20240617.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/04-EN COURS/ST JEAN DE MONTS - SCCV - LA Parée Verte/ADM/Consult/DCE  2024-06-17/PLANS ARCHITECTE/02 PLANS LOGEMENT01 20240617.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\04-EN COURS\ST JEAN DE MONTS - SCCV - LA Parée Verte\ADM\Consult\DCE  2024-06-17\PLANS ARCHITECTE\02 PLANS LOGEMENT01 20240617.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/04-EN COURS/ST JEAN DE MONTS - SCCV - LA Parée Verte/ADM/Consult/DCE  2024-06-17/PLANS ARCHITECTE/03 PLANS LOGEMENT02 20240617.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\04-EN COURS\ST JEAN DE MONTS - SCCV - LA Parée Verte\ADM\Consult\DCE  2024-06-17\PLANS ARCHITECTE\03 PLANS LOGEMENT02 20240617.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/04-EN COURS/ST JEAN DE MONTS - SCCV - LA Parée Verte/ADM/Consult/DCE  2024-06-17/PLANS ARCHITECTE/04 PLANS LOGEMENT03 20240617.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\04-EN COURS\ST JEAN DE MONTS - SCCV - LA Parée Verte\ADM\Consult\DCE  2024-06-17\PLANS ARCHITECTE\04 PLANS LOGEMENT03 20240617.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/04-EN COURS/ST JEAN DE MONTS - SCCV - LA Parée Verte/ADM/Consult/DCE  2024-06-17/PLANS ARCHITECTE/05 PLANS LOGEMENT04 20240617.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\04-EN COURS\ST JEAN DE MONTS - SCCV - LA Parée Verte\ADM\Consult\DCE  2024-06-17\PLANS ARCHITECTE\05 PLANS LOGEMENT04 20240617.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/04-EN COURS/ST JEAN DE MONTS - SCCV - LA Parée Verte/ADM/Consult/DCE  2024-06-17/PLANS ARCHITECTE/06 PLANS LOGEMENT05 20240617.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\04-EN COURS\ST JEAN DE MONTS - SCCV - LA Parée Verte\ADM\Consult\DCE  2024-06-17\PLANS ARCHITECTE\06 PLANS LOGEMENT05 20240617.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/04-EN COURS/ST JEAN DE MONTS - SCCV - LA Parée Verte/ADM/Consult/DCE  2024-06-17/PLANS ARCHITECTE/07 PLANS LOGEMENT06 20240617.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\04-EN COURS\ST JEAN DE MONTS - SCCV - LA Parée Verte\ADM\Consult\DCE  2024-06-17\PLANS ARCHITECTE\07 PLANS LOGEMENT06 20240617.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/04-EN COURS/ST JEAN DE MONTS - SCCV - LA Parée Verte/ADM/Consult/DCE  2024-06-17/PLANS ARCHITECTE/08 PLANS LOGEMENT07 20240617.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\04-EN COURS\ST JEAN DE MONTS - SCCV - LA Parée Verte\ADM\Consult\DCE  2024-06-17\PLANS ARCHITECTE\08 PLANS LOGEMENT07 20240617.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/01-CHANTIERS/04-EN COURS/ST JEAN DE MONTS - SCCV - LA Parée Verte/ADM/Consult/DCE  2024-06-17/PLANS ARCHITECTE/09 PLANS LOGEMENT07 20240617.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\01-CHANTIERS\04-EN COURS\ST JEAN DE MONTS - SCCV - LA Parée Verte\ADM\Consult\DCE  2024-06-17\PLANS ARCHITECTE\09 PLANS LOGEMENT07 20240617.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)/ADMINISTRATIF/Consultation/1 DCE CSPS_230321.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)\ADMINISTRATIF\Consultation\1 DCE CSPS_230321.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)/ADMINISTRATIF/Consultation/Attestation 2021- 52-301 - SARL ATAE.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)\ADMINISTRATIF\Consultation\Attestation 2021- 52-301 - SARL ATAE.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)/ADMINISTRATIF/Consultation/OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON/1 DCE CSPS_230321.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)\ADMINISTRATIF\Consultation\OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON\1 DCE CSPS_230321.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)/ADMINISTRATIF/Consultation/OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON/2-Note méthodologique VENDEE EAU.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)\ADMINISTRATIF\Consultation\OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON\2-Note méthodologique VENDEE EAU.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)/ADMINISTRATIF/Consultation/OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON/3 DE SPS_230321 6 sites.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)\ADMINISTRATIF\Consultation\OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON\3 DE SPS_230321 6 sites.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)/ADMINISTRATIF/Consultation/OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON/3 DE SPS_230321 RECAPITULATIF.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)\ADMINISTRATIF\Consultation\OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON\3 DE SPS_230321 RECAPITULATIF.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)/ADMINISTRATIF/Consultation/OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON/4-Attestation sur l'Honneur.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)\ADMINISTRATIF\Consultation\OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON\4-Attestation sur l'Honneur.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)/ADMINISTRATIF/Consultation/OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON/5-Attestation Assurance 2021 ATAE.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)\ADMINISTRATIF\Consultation\OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON\5-Attestation Assurance 2021 ATAE.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)/ADMINISTRATIF/Consultation/OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON/6-DC1.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)\ADMINISTRATIF\Consultation\OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON\6-DC1.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)/ADMINISTRATIF/Consultation/OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON/7-DC2 et annexes.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\APREMONT - VENDEE EAU - Réservoirs sur tour  (annulé)\ADMINISTRATIF\Consultation\OFFRE VENDEE EAU envoyée par mail le 07 04 2021 à Mme RENON\7-DC2 et annexes.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/CHALLANS - CC CHALLANS - Air accueil des Gens du Voyage (annulé)/ADMINISTRATIF/Consultation/CCTP_V3b.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\CHALLANS - CC CHALLANS - Air accueil des Gens du Voyage (annulé)\ADMINISTRATIF\Consultation\CCTP_V3b.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/CHALLANS - CC CHALLANS - Air accueil des Gens du Voyage (annulé)/ADMINISTRATIF/Consultation/Programme technique.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\CHALLANS - CC CHALLANS - Air accueil des Gens du Voyage (annulé)\ADMINISTRATIF\Consultation\Programme technique.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/CHALLANS - CHLVO - Toitures- terrasses  (annulé)/ADMINISTRATIF/Consultation/AVP RENDU/ANNEXE PLANS AVP - Copie.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\CHALLANS - CHLVO - Toitures- terrasses  (annulé)\ADMINISTRATIF\Consultation\AVP RENDU\ANNEXE PLANS AVP - Copie.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/CHALLANS - CHLVO - Toitures- terrasses  (annulé)/ADMINISTRATIF/Consultation/AVP RENDU/ANNEXE PLANS AVP.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\CHALLANS - CHLVO - Toitures- terrasses  (annulé)\ADMINISTRATIF\Consultation\AVP RENDU\ANNEXE PLANS AVP.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/CHALLANS - CHLVO - Toitures- terrasses  (annulé)/ADMINISTRATIF/Consultation/AVP RENDU/ANNEXE tableau financier TVX base.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\CHALLANS - CHLVO - Toitures- terrasses  (annulé)\ADMINISTRATIF\Consultation\AVP RENDU\ANNEXE tableau financier TVX base.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/CHALLANS - CHLVO - Toitures- terrasses  (annulé)/ADMINISTRATIF/Consultation/AVP RENDU/ANNEXE tableau financier TVX options.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\CHALLANS - CHLVO - Toitures- terrasses  (annulé)\ADMINISTRATIF\Consultation\AVP RENDU\ANNEXE tableau financier TVX options.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/CHALLANS - CHLVO - Toitures- terrasses  (annulé)/ADMINISTRATIF/Consultation/AVP RENDU/AVP TOITURE CHLVO.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\CHALLANS - CHLVO - Toitures- terrasses  (annulé)\ADMINISTRATIF\Consultation\AVP RENDU\AVP TOITURE CHLVO.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/LEGE - SDIS - toiture du CIS - (erreur pas pr nous)/ADMINISTRATIF/Consultation/03a Plan _ Travaux toiture Lege.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\LEGE - SDIS - toiture du CIS - (erreur pas pr nous)\ADMINISTRATIF\Consultation\03a Plan _ Travaux toiture Lege.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/LEGE - SDIS - toiture du CIS - (erreur pas pr nous)/ADMINISTRATIF/Consultation/03b DTA _  _ Travaux toiture Lege.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\LEGE - SDIS - toiture du CIS - (erreur pas pr nous)\ADMINISTRATIF\Consultation\03b DTA _  _ Travaux toiture Lege.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/LEGE - SDIS - toiture du CIS - (erreur pas pr nous)/ADMINISTRATIF/Consultation/04 Mémoire technique.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\LEGE - SDIS - toiture du CIS - (erreur pas pr nous)\ADMINISTRATIF\Consultation\04 Mémoire technique.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/LEGE - SDIS - toiture du CIS - (erreur pas pr nous)/ADMINISTRATIF/Consultation/Mémoire technique Blandin Travaux toiture Lege.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\LEGE - SDIS - toiture du CIS - (erreur pas pr nous)\ADMINISTRATIF\Consultation\Mémoire technique Blandin Travaux toiture Lege.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/MACHECOUL ST MEME - LAD - ZAC de Boucardiere  (annulé)/Administratif/Consultation/Annexe 2 - Planning Phase 1.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\MACHECOUL ST MEME - LAD - ZAC de Boucardiere  (annulé)\Administratif\Consultation\Annexe 2 - Planning Phase 1.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/MACHECOUL ST MEME - LAD - ZAC de Boucardiere  (annulé)/Administratif/Consultation/Cahier charges mission CSPS_Boucardière - ATAE.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\MACHECOUL ST MEME - LAD - ZAC de Boucardiere  (annulé)\Administratif\Consultation\Cahier charges mission CSPS_Boucardière - ATAE.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/MACHECOUL ST MEME - LAD - ZAC de Boucardiere  (annulé)/Administratif/Consultation/Cahier charges mission CSPS_Boucardière.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\MACHECOUL ST MEME - LAD - ZAC de Boucardiere  (annulé)\Administratif\Consultation\Cahier charges mission CSPS_Boucardière.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/MACHECOUL ST MEME - LAD - ZAC de Boucardiere  (annulé)/Administratif/Consultation/MACHECOUL - MASSE - 2017 02 28.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\MACHECOUL ST MEME - LAD - ZAC de Boucardiere  (annulé)\Administratif\Consultation\MACHECOUL - MASSE - 2017 02 28.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/MACHECOUL ST MEME - LAD - ZAC de Boucardiere  (annulé)/Administratif/Consultation/MACHECOUL - MASSE - 2017 02 28.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\MACHECOUL ST MEME - LAD - ZAC de Boucardiere  (annulé)\Administratif\Consultation\MACHECOUL - MASSE - 2017 02 28.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/00-Courriersolicitation.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\00-Courriersolicitation.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/02 Ficherenseignements SPS.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\02 Ficherenseignements SPS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/DCE TX/03-CCTP_Petit-Gast&Beausoleil.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\DCE TX\03-CCTP_Petit-Gast&Beausoleil.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/DCE TX/04-BPU_Petit-Gast&Beausoleil.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\DCE TX\04-BPU_Petit-Gast&Beausoleil.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/DCE TX/05-DE_Petit-Gast&Beausoleil.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\DCE TX\05-DE_Petit-Gast&Beausoleil.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/DCE TX/06-Planning prévisionnel-22.027.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\DCE TX\06-Planning prévisionnel-22.027.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/plans/Beausoleil/PDF/B1-Plan de situation.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\plans\Beausoleil\PDF\B1-Plan de situation.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/plans/Beausoleil/PDF/B2.1-Plan de l'état existant-Secteur Sud.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\plans\Beausoleil\PDF\B2.1-Plan de l'état existant-Secteur Sud.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/plans/Beausoleil/PDF/B2.2-Plan de l'état existant-Secteur Est.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\plans\Beausoleil\PDF\B2.2-Plan de l'état existant-Secteur Est.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/plans/Beausoleil/PDF/B3.1-Plan d'aménagement et de signalisationt-Secteur Sud.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\plans\Beausoleil\PDF\B3.1-Plan d'aménagement et de signalisationt-Secteur Sud.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/plans/Beausoleil/PDF/B3.2-Plan d'aménagement et de signalisationt-Secteur Est.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\plans\Beausoleil\PDF\B3.2-Plan d'aménagement et de signalisationt-Secteur Est.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/plans/Beausoleil/PDF/B4.1-Plan de nivellement et bordures-Secteur Sud.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\plans\Beausoleil\PDF\B4.1-Plan de nivellement et bordures-Secteur Sud.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/03- ARCHIVES/00-DOSSIER ANNULE/PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast/ADMINISTRATIF/Consultation/plans/Beausoleil/PDF/B4.2-Plan de nivellement et bordures-Secteur Est.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\03- ARCHIVES\00-DOSSIER ANNULE\PLANCHE - CLISSON SEVRE MAINE AGGLO  - PA Beau soleil & Petit Gast\ADMINISTRATIF\Consultation\plans\Beausoleil\PDF\B4.2-Plan de nivellement et bordures-Secteur Est.pdf</a>
# ...
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/00-DEVIS/DEVIS - ARCHIVES/Devis - ECHEC 2022/HAUTE GOULAINE - PODELIHA - 7 logements ind/Consultation/Lettre de consultation _ SPS.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\00-DEVIS\DEVIS - ARCHIVES\Devis - ECHEC 2022\HAUTE GOULAINE - PODELIHA - 7 logements ind\Consultation\Lettre de consultation _ SPS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/00-DEVIS/DEVIS - ARCHIVES/Devis - ECHEC 2022/ST VINCENT DES LANDES - MAIRIE - Construction bâtiment accueil périscolaire/consultation courrier.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\00-DEVIS\DEVIS - ARCHIVES\Devis - ECHEC 2022\ST VINCENT DES LANDES - MAIRIE - Construction bâtiment accueil périscolaire\consultation courrier.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/00-DEVIS/DEVIS - ARCHIVES/Devis - ECHEC 2023/MONTILLIERS - MAIRIE - Aménagement traversée bourg/Consultation/RD748_PR30+500-31+500.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\00-DEVIS\DEVIS - ARCHIVES\Devis - ECHEC 2023\MONTILLIERS - MAIRIE - Aménagement traversée bourg\Consultation\RD748_PR30+500-31+500.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/00-DEVIS/DEVIS - ARCHIVES/Devis - ECHEC 2023/MONTILLIERS - MAIRIE - Aménagement traversée bourg/Consultation/Vue en plan IndD (003).pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\00-DEVIS\DEVIS - ARCHIVES\Devis - ECHEC 2023\MONTILLIERS - MAIRIE - Aménagement traversée bourg\Consultation\Vue en plan IndD (003).pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/01-CHANTIERS/00-NOUVEAU/HERBIERS - VL - Foyer Arc en Ciel/ADMINISTRATIF/Consult/Plan travaux à faire.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\01-CHANTIERS\00-NOUVEAU\HERBIERS - VL - Foyer Arc en Ciel\ADMINISTRATIF\Consult\Plan travaux à faire.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/HERBIERS - MAIRIE -  Château de l'Etenduère/ADMINISTRATIF/Consultation/1 Plan de situation.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\HERBIERS - MAIRIE -  Château de l'Etenduère\ADMINISTRATIF\Consultation\1 Plan de situation.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/HERBIERS - MAIRIE -  Château de l'Etenduère/ADMINISTRATIF/Consultation/2 Extrait cadastral.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\HERBIERS - MAIRIE -  Château de l'Etenduère\ADMINISTRATIF\Consultation\2 Extrait cadastral.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/HERBIERS - MAIRIE -  Château de l'Etenduère/ADMINISTRATIF/Consultation/3 Plan topographique GEOUEST.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\HERBIERS - MAIRIE -  Château de l'Etenduère\ADMINISTRATIF\Consultation\3 Plan topographique GEOUEST.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/HERBIERS - MAIRIE -  Château de l'Etenduère/ADMINISTRATIF/Consultation/4 Plan d'élévations GEOUEST.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\HERBIERS - MAIRIE -  Château de l'Etenduère\ADMINISTRATIF\Consultation\4 Plan d'élévations GEOUEST.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/HERBIERS - MAIRIE -  Château de l'Etenduère/ADMINISTRATIF/Consultation/5 Diag-Plan Château de l'Etenduère.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\HERBIERS - MAIRIE -  Château de l'Etenduère\ADMINISTRATIF\Consultation\5 Diag-Plan Château de l'Etenduère.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/HERBIERS - MAIRIE -  Château de l'Etenduère/ADMINISTRATIF/Consultation/6 Photos.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\HERBIERS - MAIRIE -  Château de l'Etenduère\ADMINISTRATIF\Consultation\6 Photos.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/HERBIERS - MAIRIE -  Château de l'Etenduère/ADMINISTRATIF/Consultation/7 Photos.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\HERBIERS - MAIRIE -  Château de l'Etenduère\ADMINISTRATIF\Consultation\7 Photos.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/HERBIERS - MAIRIE -  Château de l'Etenduère/ADMINISTRATIF/Consultation/8 Photos.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\HERBIERS - MAIRIE -  Château de l'Etenduère\ADMINISTRATIF\Consultation\8 Photos.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/HERBIERS - MAIRIE -  Château de l'Etenduère/ADMINISTRATIF/Consultation/Notice descriptive chateau Etenduère mission SPS.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\HERBIERS - MAIRIE -  Château de l'Etenduère\ADMINISTRATIF\Consultation\Notice descriptive chateau Etenduère mission SPS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/MONTAIGU (BOUFFERE) - MAIRIE - Eglise/Administratif/Consultation/08. Estimatif des travaux.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\MONTAIGU (BOUFFERE) - MAIRIE - Eglise\Administratif\Consultation\08. Estimatif des travaux.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/MONTAIGU (BOUFFERE) - MAIRIE - Eglise/Administratif/Consultation/GPAU 2021.11.MM- consultation FR ATAE.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\MONTAIGU (BOUFFERE) - MAIRIE - Eglise\Administratif\Consultation\GPAU 2021.11.MM- consultation FR ATAE.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/MONTAIGU - EDMP PAYS DE LOIRE  (E. DENIS) - 57 logmts Moonatica/ADMINISTRATIF/Consultation/H00_FAISA EDOUARD DENIS MONTAIGU_SYNTHESE PLAN MASSE.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\MONTAIGU - EDMP PAYS DE LOIRE  (E. DENIS) - 57 logmts Moonatica\ADMINISTRATIF\Consultation\H00_FAISA EDOUARD DENIS MONTAIGU_SYNTHESE PLAN MASSE.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2024/PIERRE PERCEE - CCSL - CONSTRUCTION HALTE VELO/ADMINISTRATIF/Consultation_SPS_Belvédère Halte vélos_Pierre Percée.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2024\PIERRE PERCEE - CCSL - CONSTRUCTION HALTE VELO\ADMINISTRATIF\Consultation_SPS_Belvédère Halte vélos_Pierre Percée.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHAVAGNES LES REDOUX - MAIRIE + VE - Aménagement Le Lavoir/ADMINISTRATIF/Consultation/31413 - Pièce 4.2 - CCTP Lot 1 .pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHAVAGNES LES REDOUX - MAIRIE + VE - Aménagement Le Lavoir\ADMINISTRATIF\Consultation\31413 - Pièce 4.2 - CCTP Lot 1 .pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHAVAGNES LES REDOUX - MAIRIE + VE - Aménagement Le Lavoir/ADMINISTRATIF/Consultation/31413 - Pièce 4.2 - CCTP Lot 1 .pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHAVAGNES LES REDOUX - MAIRIE + VE - Aménagement Le Lavoir\ADMINISTRATIF\Consultation\31413 - Pièce 4.2 - CCTP Lot 1 .pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHAVAGNES LES REDOUX - MAIRIE + VE - Aménagement Le Lavoir/ADMINISTRATIF/Consultation/31413 - Pièce 4.2 - CCTP Lot 2 .pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHAVAGNES LES REDOUX - MAIRIE + VE - Aménagement Le Lavoir\ADMINISTRATIF\Consultation\31413 - Pièce 4.2 - CCTP Lot 2 .pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHAVAGNES LES REDOUX - MAIRIE + VE - Aménagement Le Lavoir/ADMINISTRATIF/Consultation/31413 - Pièce 4.2 - CCTP Lot 2 .pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHAVAGNES LES REDOUX - MAIRIE + VE - Aménagement Le Lavoir\ADMINISTRATIF\Consultation\31413 - Pièce 4.2 - CCTP Lot 2 .pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHAVAGNES LES REDOUX - MAIRIE + VE - Aménagement Le Lavoir/ADMINISTRATIF/Consultation/31413 -Pièce 4.1 - CCTP généralités.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHAVAGNES LES REDOUX - MAIRIE + VE - Aménagement Le Lavoir\ADMINISTRATIF\Consultation\31413 -Pièce 4.1 - CCTP généralités.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHOLET - REGION - LYCEE EUROPE SCHUMAN/ADMINISTRATIF/Consultation/13D02811-note de présentation CSPS.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHOLET - REGION - LYCEE EUROPE SCHUMAN\ADMINISTRATIF\Consultation\13D02811-note de présentation CSPS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHOLET - REGION - LYCEE EUROPE SCHUMAN/ADMINISTRATIF/Consultation/ATAE CSPS  RPDL Lycée Europe Robert Schuman.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHOLET - REGION - LYCEE EUROPE SCHUMAN\ADMINISTRATIF\Consultation\ATAE CSPS  RPDL Lycée Europe Robert Schuman.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHOLET - REGION - LYCEE EUROPE SCHUMAN/ADMINISTRATIF/Consultation/CCAP_EUROPE SCHUMAN_CSPS .pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHOLET - REGION - LYCEE EUROPE SCHUMAN\ADMINISTRATIF\Consultation\CCAP_EUROPE SCHUMAN_CSPS .pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHOLET - REGION - LYCEE EUROPE SCHUMAN/ADMINISTRATIF/Consultation/CCTP_EUROPE SHCUMAN_CSPS .pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHOLET - REGION - LYCEE EUROPE SCHUMAN\ADMINISTRATIF\Consultation\CCTP_EUROPE SHCUMAN_CSPS .pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHOLET - REGION - LYCEE EUROPE SCHUMAN/ADMINISTRATIF/Consultation/DCE_Stratégie d'achat.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHOLET - REGION - LYCEE EUROPE SCHUMAN\ADMINISTRATIF\Consultation\DCE_Stratégie d'achat.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHOLET - REGION - LYCEE EUROPE SCHUMAN/ADMINISTRATIF/Consultation/Livre1-REFERENTIEL SOBRIETE_V2_05-nov-19.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHOLET - REGION - LYCEE EUROPE SCHUMAN\ADMINISTRATIF\Consultation\Livre1-REFERENTIEL SOBRIETE_V2_05-nov-19.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CHOLET - REGION - LYCEE EUROPE SCHUMAN/ADMINISTRATIF/Consultation/RC_EUROPE SCHUMAN_CSPS.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CHOLET - REGION - LYCEE EUROPE SCHUMAN\ADMINISTRATIF\Consultation\RC_EUROPE SCHUMAN_CSPS.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CUGAND - SMFA - Poste de Refoulement/ADMINISTRATIF/Consultation/202304 4-51-3501 - PR CUGAND - CCTP lot 1.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CUGAND - SMFA - Poste de Refoulement\ADMINISTRATIF\Consultation\202304 4-51-3501 - PR CUGAND - CCTP lot 1.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CUGAND - SMFA - Poste de Refoulement/ADMINISTRATIF/Consultation/202304 4-51-3501 - PR CUGAND - CCTP lot 1.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CUGAND - SMFA - Poste de Refoulement\ADMINISTRATIF\Consultation\202304 4-51-3501 - PR CUGAND - CCTP lot 1.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CUGAND - SMFA - Poste de Refoulement/ADMINISTRATIF/Consultation/202304 4-51-3501 - PR CUGAND - CCTP lot 2.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CUGAND - SMFA - Poste de Refoulement\ADMINISTRATIF\Consultation\202304 4-51-3501 - PR CUGAND - CCTP lot 2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CUGAND - SMFA - Poste de Refoulement/ADMINISTRATIF/Consultation/202304 4-51-3501 - PR CUGAND - CCTP lot 2.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CUGAND - SMFA - Poste de Refoulement\ADMINISTRATIF\Consultation\202304 4-51-3501 - PR CUGAND - CCTP lot 2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/CUGAND - SMFA - Poste de Refoulement/ADMINISTRATIF/Consultation/PR Cugand_Implantation V4-PR CUGAND.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\CUGAND - SMFA - Poste de Refoulement\ADMINISTRATIF\Consultation\PR Cugand_Implantation V4-PR CUGAND.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/HERBIERS - SDIS 85 - centre de secours/ADMINISTRATIF/Consultation/CS LH plan existant 2001 2012.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\HERBIERS - SDIS 85 - centre de secours\ADMINISTRATIF\Consultation\CS LH plan existant 2001 2012.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/HERBIERS - SDIS 85 - centre de secours/ADMINISTRATIF/Consultation/CS LH plan projet rea 260922.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\HERBIERS - SDIS 85 - centre de secours\ADMINISTRATIF\Consultation\CS LH plan projet rea 260922.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/HERBIERS - SDIS 85 - centre de secours/ADMINISTRATIF/Consultation/CS LH plan projet rea detail 260922.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\HERBIERS - SDIS 85 - centre de secours\ADMINISTRATIF\Consultation\CS LH plan projet rea detail 260922.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/MAULEON - TERRENA - Ext magasin/ADMINISTRATIF/Consult/Accord ATAE.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\MAULEON - TERRENA - Ext magasin\ADMINISTRATIF\Consult\Accord ATAE.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/MAULEON - TERRENA - Ext magasin/ADMINISTRATIF/Consult/PLP-MAULE1-Façade Coupe.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\MAULEON - TERRENA - Ext magasin\ADMINISTRATIF\Consult\PLP-MAULE1-Façade Coupe.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/MAULEON - TERRENA - Ext magasin/ADMINISTRATIF/Consult/PLP-MAULE1-Vue en plan.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\MAULEON - TERRENA - Ext magasin\ADMINISTRATIF\Consult\PLP-MAULE1-Vue en plan.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/ST GEORGES DE MONTAIGU - MAIRIE - Dronneau Maines/ADMINISTRATIF/Consultation/Phasage travaux.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\ST GEORGES DE MONTAIGU - MAIRIE - Dronneau Maines\ADMINISTRATIF\Consultation\Phasage travaux.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/ST GEORGES DE MONTAIGU - MAIRIE - Dronneau Maines/ADMINISTRATIF/Consultation/Plan de situation.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\ST GEORGES DE MONTAIGU - MAIRIE - Dronneau Maines\ADMINISTRATIF\Consultation\Plan de situation.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/ST GEORGES DE MONTAIGU - MAIRIE - Dronneau Maines/ADMINISTRATIF/Consultation/Plan des travaux - Lot n°1.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\ST GEORGES DE MONTAIGU - MAIRIE - Dronneau Maines\ADMINISTRATIF\Consultation\Plan des travaux - Lot n°1.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/ST GEORGES DE MONTAIGU - MAIRIE - Dronneau Maines/ADMINISTRATIF/Consultation/Plan des travaux - Lot n°2.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\ST GEORGES DE MONTAIGU - MAIRIE - Dronneau Maines\ADMINISTRATIF\Consultation\Plan des travaux - Lot n°2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Yann HERVE - YANN/04-ARCHIVES/2025/ST GEORGES DE MONTAIGU - MAIRIE - Dronneau Maines/ADMINISTRATIF/Consultation/Planning prévisionnel.pdf">C:\Users\jch_m\ATAE\Yann HERVE - YANN\04-ARCHIVES\2025\ST GEORGES DE MONTAIGU - MAIRIE - Dronneau Maines\ADMINISTRATIF\Consultation\Planning prévisionnel.pdf</a>

# %%
TableReport(df_consult_ebp)
# Out:
# Processing column  10 / 10
# <TableReport: use .open() to display>

# %%
# Creation d'un DF_consult_elevated avec une ligne par "EBP ID", 
# et l'ajout des features resultants de l'extraction 

df_consult_ao = df_consult_ebp[df_consult_ebp['AO_docs']==True]
df_consult_elevated = df_consult_ao.drop_duplicates(subset=["ID EBP"], keep="first")

# Suppression des colonnes desormais inutiles
df_consult_elevated = df_consult_elevated.drop(columns=['file_path','file_name','AO_docs','AO_doc_type'])

# %%
df_consult_elevated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 926 entries, 0 to 158400
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SPS Name        926 non-null    object
#  1   Ville           926 non-null    object
#  2   Entreprise      926 non-null    object
#  3   Mission         926 non-null    object
#  4   statut_consult  926 non-null    object
#  5   ID EBP          926 non-null    object
# dtypes: object(6)
# memory usage: 50.6+ KB

# %% [markdown]
# # Definition des prompts et functions d'extractions

# %%
# Prompts pour la collection des infos par type de document
#
prompt_role = "your are an assistant to analyse the bids for Coordination SPS, extract key informations followins the specified instructions in term of format and content"

###### ---- CCTP -------------- ###################
format_json_cctp = {
    "Nom Chantier": "",
    "Lieu du Chantier": "",
    "Maitre ouvrage": "",
    "Maitre oeuvre": "",
    "Type de Travaux": "",
    "Planning phase conception": "",
    "Planning phase realisation": "",
    "Prix des travaux": 0,
    "Duree des travaux": 0,
    "Categorie operation SPS": "",
} 
json_string_cctp = json.dumps(format_json_cctp, ensure_ascii=False, indent=2)

prompt_resumer_cctp = """
En Francais, extraire du **Texte CCxP** les **Informations** suivantes : 

**Informations**:
'Nom Chantier': scope du projet, objet du chantier, objectif du programme, 
'Lieu du Chantier': ville  Commune  Departement Rue , 
'Maitre ouvrage': nom du Maitre d'ouvrage du projet,
'Maitre oeuvre': nom du maitre d'oeuvre du chantier ,
'Type de Travaux': type et nature du travaux du chantier exemple: amenagement construction ,
'Planning phase conception': date et duree Previsionnelle, 
'Planning phase realisation': date et duree Previsionnelle, 
'Prix des travaux' : en euros HT <integer>, 
'Durée Prévisionnelle des Travaux': en nombre de mois <integer>,
'Categorie operation SPS':  I II ou III, 

**Instructions**: 
Donne uniquement les informations disponibles dans le texte CCxP, sans interpretation ou estimation. 
Donne des reponses chiffrées et quantifiées lorsque c'est possible. 
La reponse doit etre ecrite en francais et avoir un maximum 900 mots 
Réponds uniquement aux informations demandées qui sont toutes dans le texte

**Texte CCxP**: 
"""

prompt_json_cctp = f"""
Format the output, focusing on informations requested and available within the **Text** and initial document . 
Do not invent anything. 
Strickly follow the JSON format request. Write in French: \n{json_string_cctp}\

**Text**: 
"""

###### ---- Reglement -------------- ###################
format_json_regl = {
    "Critere Prix": 0,
    "Critere Technique": {
        "global": 0,
        "details": {
            "Moyen Humain et Experience": 0,
            "Methodologie": 0,
            "Cohérence du temps": 0,
            "Compréhension des enjeux": 0,
        }
    },
    "Prix des travaux": 0,
    "Duree des travaux": 0,
}
string_json_regl = json.dumps(format_json_regl, ensure_ascii=False, indent=2)

prompt_resumer_regl = """ 
Extract from **Texte** the following informations related to 'evaluation et critère de l'offre'  : 

**Informations**:
'Critère Prix': quel poid ou ponderation pour le critère de l'examen du prix des prestations , valeur de la note maximale ? <integer>,
'Critère Technique' : quel poids ou ponderations pour le critère de l'examen la valeur technique de l'offre ? et detaillant si disponible les sous-critères suivants <integer>,
'Moyen Humain et Experience': quel poids pour la compétences, moyen matériel ? <integer>,
'Methodologie': quel poids ou note pour ce sous-critère de la methode technique ? <integer>,
'Cohérence du temps': quel poids ou note pour ce sous-critère du temps de travail estimé pour ce service ? <integer>,
'Compréhension des enjeux': quel poids ou note pour ce sous-critère Compréhension des enjeux pour ce service ? <integer>,, 
'Prix des travaux' : en euros HT <integer>, 
'Durée Prévisionnelle des Travaux': en nombre de mois <integer>,

**Instructions**: 
Donne uniquement les informations disponibles dans le texte , sans interpretation ou estimation. 
Donne des reponses chiffrées et quantifiées lorsque c'est possible. 
La reponse doit etre ecrite en francais et avoir un maximum 500 mots 
Réponds uniquement aux informations demandées qui sont toutes dans le texte

**Texte**: 
"""

prompt_json_regl = f"""
Format the output, focusing on informations requested and available within the **Text** and initial document . 
Do not invent anything. 
Strickly follow the JSON format request. Write in French: 
{string_json_regl}

**Text**: \n 
""" 

###### ---- AAPC -------------- ###################
format_json_aapc = {
    "Mission": "",
    "Lieu du Chantier": "",
    "Maitre ouvrage": "",
    "Lot": "",
    "Tranche": "",
    "Prix des travaux": 0,
    "Duree des travaux": 0,
}
string_json_aapc = json.dumps(format_json_aapc, ensure_ascii=False, indent=2)

prompt_resumer_aapc = """ 
Extract from **Texte** the following informations related to 'evaluation et critère de l'offre'  : 

**Informations**:
'Mission': scope du projet, objet du chantier, objectif du programme, 
'Lieu du Chantier': ville  Commune  Departement Rue , 
'Maitre ouvrage': nom du Maitre d'ouvrage du projet,
'Tranche': le projet est il decoupé en plusieurs Tranche ou phases ex '2 tranches', 'non'
'Lot': le projet est il decoupé en plusieurs lots, ex '3 lots', 'non',
'Prix des travaux' : en euros HT, <integer>,
'Durée des Travaux': en nombre de mois, <integer>,

**Instructions**: 
Donne uniquement les informations disponibles dans le texte , sans interpretation ou estimation. 
Donne des reponses chiffrées et quantifiées lorsque c'est possible. 
La reponse doit etre ecrite en francais et avoir un maximum 500 mots 
Réponds uniquement aux informations demandées qui sont toutes dans le texte

**Texte**: 
"""

prompt_json_aapc = f"""
Format the output, focusing on informations requested and available within the **Text** and initial document . 
Do not invent anything. 
Strickly follow the JSON format request. Write in French: 
{string_json_aapc}

**Text**: \n 
""" 

###### ---- CCAP -------------- ###################
format_json_ccap= {
    "Objet du marché": "",
    "Lieu du Chantier": "",
    "Maitre ouvrage": "",
    "Maitre oeuvre": "",
    "tranche": "",
    "Lot": "",
}
string_json_ccap = json.dumps(format_json_ccap, ensure_ascii=False, indent=2)

prompt_resumer_ccap = """ 
Extract from **Texte** the following informations related to 'evaluation et critère de l'offre'  : 

**Informations**:
'Objet du marché': scope du projet, objet du chantier, objectif du programme, 
'Lieu du Chantier': ville  Commune  Departement Rue , 
'Maitre ouvrage': nom du Maitre d'ouvrage du projet,
'Maitre oeuvre': nom du Maitre d'oeuvre du projet, en phase de conception et de realisation 
'Tranche': le projet est il decoupé en plusieurs tranches, ex '2 tranches', 'non',
'Lot': le projet est il decoupé en plusieurs lot, ex '3 lots', 'non',

**Instructions**: 
Donne uniquement les informations disponibles dans le texte , sans interpretation ou estimation. 
Donne des reponses chiffrées et quantifiées lorsque c'est possible. 
La reponse doit etre ecrite en francais et avoir un maximum 500 mots 
Réponds uniquement aux informations demandées qui sont toutes dans le texte

**Texte**: 
"""

prompt_json_ccap = f"""
Format the output, focusing on informations requested and available within the **Text** and initial document . 
Do not invent anything. 
Strickly follow the JSON format request. Write in French: 
{string_json_ccap}

**Text**: \n 
"""

# %%
# Init Ollama, with list of model, prompt

ollama_url = "http://localhost:11434"

# Get an ollama client
llmclient = Client(host=ollama_url)
model_options = {
    "num_predict": 1300,  # max number of tokens to predict
    "temperature": 0.05,
    "top_p": 0.2,
    "num_ctx": 9000 # max number of tokens to input
}
"""
model_options_json = {
    "num_predict": 1300,  # max number of tokens to predict
    "temperature": 0.05,
    "top_p": 0.2,
    "format": "json",
    "num_ctx": 9000 # max number of tokens to input
}
"""

# 'mistral-small3.1=14G  llama3.2:latest=2G gemma3:4b=3.3G
#list_model = ["gemma3:4b", "llama3.2", "minicpm-v", "mistral-small3.1"]
list_model = ["gemma3:12b", "gemma2:9b", "llama3.1:8b", "mistral:7b"]

MODEL_ID = "gemini-2.5-flash-preview-05-20" # @param ["gemini-2.0-flash-lite","gemini-2.0-flash","gemini-2.5-flash-preview-05-20","gemini-2.5-pro-preview-06-05"] {"allow-input":true, isTemplate: true}
Genaiclient = genai.Client(api_key=os.environ['GOOGLE_API_KEY'])

response = Genaiclient.models.generate_content(
    model=MODEL_ID,
    contents="How to be happy today?"
)
#display(Markdown(response.text))
print(response.text)
# Out:
# Being happy today isn't about achieving a state of constant euphoria, but rather about cultivating moments of contentment, gratitude, and peace, and effectively managing moments of stress or negativity.
#
# Here are some actionable tips you can try *today*:
#
# 1.  **Start with Gratitude:** Before you even get out of bed, think of 3 things you're grateful for. They can be tiny (the warm blanket, a cup of coffee) or significant (your health, a loved one). This immediately shifts your focus.
#
# 2.  **Hydrate and Nourish:** Drink a glass of water. Eat a nutritious meal that you enjoy. Your physical well-being strongly impacts your mood.
#
# 3.  **Move Your Body:** Even 5-10 minutes can make a difference. Stretch, do a few jumping jacks, walk around the block, dance to your favorite song. Movement releases endorphins.
#
# 4.  **Do One Small Productive Thing:** Tidy a small area, send that email you've been putting off, or complete a single task on your to-do list. The feeling of accomplishment, even tiny, boosts your mood.
#
# 5.  **Connect with Someone:** Send a quick text to a friend or family member, make a short phone call, or simply smile at a stranger. Human connection is vital.
#
# 6.  **Engage Your Senses:**
#     *   **Listen:** Put on uplifting music, or just notice the sounds around you.
#     *   **Smell:** Light a candle, use an essential oil diffuser, or brew some coffee/tea.
#     *   **See:** Look out a window, notice the colors in your environment, or look at a picture that makes you smile.
#     *   **Taste:** Savor a piece of fruit, or a square of chocolate.
#     *   **Touch:** Pet an animal, feel the texture of your clothes, or hug someone.
#
# 7.  **Practice Mindfulness/Presence:** For a few minutes, just focus on one thing: your breath, the taste of your food, the feeling of the sun on your skin. This brings you into the present moment and reduces overthinking.
#
# 8.  **Limit Negative Input:** Be mindful of how much news you consume, or if certain social media accounts make you feel bad. Take a break if needed.
#
# 9.  **Be Kind to Yourself:** Notice if you're being overly self-critical. Treat yourself with the same compassion you'd offer a friend. Say "It's okay" if things aren't perfect.
#
# 10. **Do Something Just for Fun (No Goal):** Doodle, read a chapter of a book, watch a silly video, play a game. Give yourself permission to enjoy.
#
# 11. **Get Outside (Even Briefly):** Fresh air and natural light can significantly improve mood. Look at the sky, a tree, or feel the wind.
#
# **Key Takeaway:** You don't have to do all of these! Pick one or two that resonate with you right now and give them a try. Happiness often comes from a series of small, intentional actions throughout the day rather than one big event. Be patient and kind with yourself.

# %%
## Run GOOGLE GENAI with predeifned prompt for avery file/text 
##
def run_genai_docs(text_from_file, prompt_resumer,prompt_json ):
    #Resumer
    prompt_full_r = prompt_resumer + text_from_file
    result = Genaiclient.models.generate_content(model=MODEL_ID,  contents=prompt_full_r)
    #bid_utils.print_text_wrapped(f"\nLLM response pour resumer: \n" + result.text)
    
    #JSON
    prompt_full_j = prompt_json + result.text
    result = Genaiclient.models.generate_content(model=MODEL_ID,  contents=prompt_full_j)
    #bid_utils.print_text_wrapped(f"\nLLM response pour JSON: \n{result.text}")
    return(result.text)

# %%
## Run all models for the same task (prompt + file) for comparison
##

def run_model_CCTP(text_from_file, model_name):
    #Init system:
    llmclient.chat(model=model_name, options=model_options, messages=[{'role':'system','content': prompt_role}])
    
    #Resumer
    prompt_full_r = prompt_resumer_cctp + text_from_file
    result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_r}])
    #result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_r}])
    #pprint(result, compact=True)
    #bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s \n" + result.message.content)
    bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s")
    
    #JSON
    prompt_full_j = prompt_json_cctp + result.message.content
    result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_j}], format='json')
    #pprint(result, compact=True)
    #bid_utils.print_text_wrapped(f"\nLLM response pour JSON: in {result['total_duration']/10**9:.0f}s \n{result.message.content}")
    return(result.message.content)


def run_model_reglement(text_from_file, model_name):
    #Init system:
    llmclient.chat(model=model_name, options=model_options, messages=[{'role':'system','content': prompt_role}])
    
    #Resumer
    prompt_full_r = prompt_resumer_regl + text_from_file
    result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_r}])
    #result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_r}])
    #pprint(result, compact=True)
    #bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s \n" + result.message.content)
    bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s")

    #JSON
    prompt_full_j = prompt_json_regl + result.message.content
    result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_j}], format='json')
    #pprint(result, compact=True)
    #bid_utils.print_text_wrapped(f"\nLLM response pour JSON: in {result['total_duration']/10**9:.0f}s \n{result.message.content}")
    return(result.message.content)


def run_model_aapc(text_from_file, model_name):
    #Init system:
    llmclient.chat(model=model_name, options=model_options, messages=[{'role':'system','content': prompt_role}])
    
    #Resumer
    prompt_full_r = prompt_resumer_aapc + text_from_file
    result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_r}])
    #result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_r}])
    #pprint(result, compact=True)
    #bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s \n" + result.message.content)
    #bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s")

    #JSON
    prompt_full_j = prompt_json_aapc + result.message.content
    result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_j}], format='json')
    #pprint(result, compact=True)
    #bid_utils.print_text_wrapped(f"\nLLM response pour JSON: in {result['total_duration']/10**9:.0f}s \n{result.message.content}")
    return(result.message.content)


def run_model_ccap(text_from_file, model_name):
    #Init system:
    llmclient.chat(model=model_name, options=model_options, messages=[{'role':'system','content': prompt_role}])
    
    #Resumer
    prompt_full_r = prompt_resumer_ccap + text_from_file
    result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_r}])
    #result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_r}])
    #pprint(result, compact=True)
    #bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s \n" + result.message.content)
    bid_utils.print_text_wrapped(f"\nLLM response pour resumer: in {result['total_duration']/10**9:.0f}s")
    
    #JSON
    prompt_full_j = prompt_json_ccap + result.message.content
    result = llmclient.chat(model=model_name, options=model_options, messages=[{'role':'user','content':prompt_full_j}], format='json')
    #pprint(result, compact=True)
    #bid_utils.print_text_wrapped(f"\nLLM response pour JSON: in {result['total_duration']/10**9:.0f}s \n{result.message.content}")
    return(result.message.content)

# %%
# Teste plusieurs models sur l'enchaienement d'analyse de fichiers pour 1 EBP ID
def test_models_for_1_ebp(list_model_to_test):
    ebp_id_l = ["no EBP 13"] # impose ce projet "no EBP 13" => CCTP,CCAP, Regl  / #no EBP 9717
    ebp_id = ebp_id_l[0]
    list_consult_type = ['Lettre Consult', 'CCP', 'CCTP', 'CCAP', 'Planning', 'AAPC', 'Reglement']

    #filtered_row = df_consult_ebp[df_consult_ebp['ID EBP'] == selected_ebp_id[0]].iloc[0]
    #print(f"\n ***** ID:{selected_ebp_id} statut_consult: {filtered_row['statut_consult']} ****** ")
    filtered_row = df_consult_ebp[df_consult_ebp['ID EBP'] == ebp_id].iloc[0]
    print(f"\n ***** ID:{ebp_id} statut_consult: {filtered_row['statut_consult']} ***** ")
    print(f"Ville:{filtered_row['Ville']}  Entreprise:{filtered_row['Entreprise']}  Mission:{filtered_row['Mission']}")
    
    for model_name in list_model_to_test:
        print(f" ===================== {model_name} ==========================")
        for doc_type in list_consult_type:
            list_file_consult = df_consult_ebp[(df_consult_ebp['ID EBP'] == ebp_id) & (df_consult_ebp['AO_doc_type'] == doc_type)]['file_path']
        
            if not list_file_consult.empty:
                print("Doc type:",doc_type)
                text_multi_files = ""
                for file_path in list_file_consult:
                    #nb_segment = file_path.split("\\")
                    #print("==> ", nb_segment[-1].strip())
                    bid_utils.path_to_link(file_path.strip(), option=None)
                    text_file = bid_utils.loadpdf_as_text(file_path.strip())
                    text_multi_files += text_file + "\n" # Contatenate text
                
                # Trim text to suppress long' '
                text_input = re.sub(r'\s+', ' ', text_multi_files).strip()
                
                # Run model for each doc type
                if doc_type == "CCTP" or doc_type == "CCP" or doc_type == "Lettre Consult" or doc_type == "Planning" :
                    json_result = run_genai_docs(text_input, prompt_resumer_cctp, prompt_json_cctp)
                    #bid_utils.update_df_with_json_cctp(json_result , ebp_id, df_consult_elevated)
                   
                if doc_type == "Reglement" or doc_type == "Lettre Consult":
                    json_result = run_genai_docs(text_input, prompt_resumer_regl, prompt_json_regl)
                    #bid_utils.update_df_with_json_regl(json_result , ebp_id, df_consult_elevated)
                    
                if doc_type == "AAPC" or doc_type == "Planning":
                    json_result = run_genai_docs(text_input,  prompt_resumer_aapc, prompt_json_aapc)
                    #bid_utils.update_df_with_json_aapc(json_result , ebp_id, df_consult_elevated)
                   
                if doc_type == "CCAP" or doc_type == "CCP" or doc_type == "Planning":
                    json_result = run_genai_docs(text_input,  prompt_resumer_ccap, prompt_json_ccap)
                    #bid_utils.update_df_with_json_ccap(json_result , ebp_id, df_consult_elevated)
                
#list_model = ["gemma3:4b", "gemma3:12b", "gemma2:9b", "llama3.1:8b", "llama3.2:latest", "qwen3:8b"]
list_model = [MODEL_ID]
test_models_for_1_ebp(list_model)

# %% [markdown]
# # Main part
# - boucle pour extraire les infos
# - verification des infos collectées

# %%
#### Enchainement des de l'extraction des docs d'un projet pour cumuler les infos.

# modele fixé
model_name = MODEL_ID # ou "llama3.2:latest" "gemma3:4b"

# Liste ordonnées des types de doc Consult à explorer
list_consult_type = ['Lettre Consult', 'CCP', 'CCTP', 'CCAP', 'Planning', 'AAPC', 'Reglement']

consult_mask = (df_consult_ebp['AO_docs'] == True) 
#cctp_mask = df_consult_ebp['AO_doc_type'] == "CCTP"

consult_ebp_ids = df_consult_ebp.loc[consult_mask, 'ID EBP'].unique()
print(f"il y a {len(consult_ebp_ids)} projets avec au moins 1 document du type 'Consultation' ")
print("nb de fichiers AO_docs avec un type identifié:",len(df_consult_ebp['AO_doc_type']) - len(df_consult_ebp[df_consult_ebp['AO_doc_type']=='no type']))

count = 0
start_exec = 0
max_count = 101
nb_model_called = 0
count_ebp_model = 0 

for ebp_id in consult_ebp_ids:

    filtered_row = df_consult_ebp[df_consult_ebp['ID EBP'] == ebp_id].iloc[0]
    print(f"\n ***** {count+1}/{max_count}:  ID:{ebp_id} statut_consult: {filtered_row['statut_consult']} ***** ")
    print(f"Ville:{filtered_row['Ville']}  Entreprise:{filtered_row['Entreprise']}  Mission:{filtered_row['Mission']}")

    for doc_type in list_consult_type:
        list_file_consult = df_consult_ebp[(df_consult_ebp['ID EBP'] == ebp_id) & (df_consult_ebp['AO_doc_type'] == doc_type)]['file_path']
        flag_callmodel = False
        if not list_file_consult.empty:
            print("Doc type:",doc_type)
            text_multi_files = ""
            for file_path in list_file_consult:
                #nb_segment = file_path.split("\\")
                #print("==> ", nb_segment[-1].strip())
                bid_utils.path_to_link(file_path.strip(), option=None)
                text_file = bid_utils.loadpdf_as_text(file_path.strip())
                text_multi_files += text_file + "\n" # Contatenate text
            
            # Trim text to suppress long' '
            text_input = re.sub(r'\s+', ' ', text_multi_files).strip()

            if count >= start_exec:
                # Run model for each doc type
                flag_callmodel = True
                if doc_type == "CCTP" or doc_type == "CCP" or doc_type == "Lettre Consult" or doc_type == "Planning" :
                    json_result = run_genai_docs(text_input, prompt_resumer_cctp, prompt_json_cctp)
                    bid_utils.update_df_with_json_cctp(json_result , ebp_id, df_consult_elevated)
                    nb_model_called += 1
                if doc_type == "Reglement" or doc_type == "Lettre Consult":
                    json_result = run_genai_docs(text_input, prompt_resumer_regl, prompt_json_regl)
                    bid_utils.update_df_with_json_regl(json_result , ebp_id, df_consult_elevated)
                    nb_model_called += 1
                if doc_type == "AAPC" or doc_type == "Planning":
                    json_result = run_genai_docs(text_input, prompt_resumer_aapc, prompt_json_aapc)
                    bid_utils.update_df_with_json_aapc(json_result , ebp_id, df_consult_elevated)
                    nb_model_called += 1
                if doc_type == "CCAP" or doc_type == "CCP" or doc_type == "Planning":
                    json_result = run_genai_docs(text_input, prompt_resumer_ccap, prompt_json_ccap)
                    bid_utils.update_df_with_json_ccap(json_result , ebp_id, df_consult_elevated)
                    nb_model_called += 1
    count_ebp_model += 1
    if count_ebp_model % 50 == 0:
        df_consult_elevated.to_pickle(path_df_consult_elevated)
        print(f"\nCount {count_ebp_model}: DataFrame successfully saved to '{path_df_consult_elevated}'")

    if count > max_count:
        break
    count += 1
# Out:
# il y a 926 projets avec au moins 1 document du type 'Consultation'
# nb de fichiers AO_docs avec un type identifié: 829
#
#  ***** 1/101:  ID:no EBP 1 statut_consult: Perdu *****
# Ville:BOUGUENAIS  Entreprise:BGTA Ministère environnement  Mission:Sécurisation BGTA
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2022/00-Echec 2022/BOUGUENAIS - BGTA Ministère environnement - Sécurisation BGTA/CONSULTATION/0SNIA_Ouest_22_006_RC_V1_0 (1).pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2022\00-Echec 2022\BOUGUENAIS - BGTA Ministère environnement - Sécurisation BGTA\CONSULTATION\0SNIA_Ouest_22_006_RC_V1_0 (1).pdf</a>
#  ***** 2/101:  ID:no EBP 3 statut_consult: Devis *****
# Ville:BOUGUENAIS  Entreprise:MAIRIE  Mission:Salle de sport Joel Dubois et Cossec
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/CCTP Hors lots techniques janvier 2023.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\CCTP Hors lots techniques janvier 2023.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2023/BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec/Consultation/CCTP Lots techniques BOUGUENAIS_AVP janvier 2023.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2023\BOUGUENAIS - MAIRIE - Salle de sport Joel Dubois et Cossec\Consultation\CCTP Lots techniques BOUGUENAIS_AVP janvier 2023.pdf</a>
#  ***** 3/101:  ID:no EBP 13 statut_consult: Perdu *****
# Ville:ST NAZAIRE  Entreprise:SONADEV  Mission:CONSTRUCTION GROUPE SCOLAIRE
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2024/00-Echec 2024/ST NAZAIRE - SONADEV - CONSTRUCTION GROUPE SCOLAIRE/Consultation/CCTP CSPS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2024\00-Echec 2024\ST NAZAIRE - SONADEV - CONSTRUCTION GROUPE SCOLAIRE\Consultation\CCTP CSPS.pdf</a>
# Doc type: AAPC
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2024/00-Echec 2024/ST NAZAIRE - SONADEV - CONSTRUCTION GROUPE SCOLAIRE/Consultation/AAPC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2024\00-Echec 2024\ST NAZAIRE - SONADEV - CONSTRUCTION GROUPE SCOLAIRE\Consultation\AAPC.pdf</a>
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2024/00-Echec 2024/ST NAZAIRE - SONADEV - CONSTRUCTION GROUPE SCOLAIRE/Consultation/RC CSPS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2024\00-Echec 2024\ST NAZAIRE - SONADEV - CONSTRUCTION GROUPE SCOLAIRE\Consultation\RC CSPS.pdf</a>
#  ***** 4/101:  ID:no EBP 15 statut_consult: Devis *****
# Ville:PORNIC  Entreprise:LAD  Mission:démolition
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2024/PORNIC - LAD - démolition/Consultation/CCTP_CSPS_RueGeneraldeGaulle.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2024\PORNIC - LAD - démolition\Consultation\CCTP_CSPS_RueGeneraldeGaulle.pdf</a>
#  ***** 5/101:  ID:no EBP 16 statut_consult: Devis *****
# Ville:ST HERBLAIN  Entreprise:VLOK  Mission:Réhab Bat industriel en AGENCE V-LOK
#
#  ***** 6/101:  ID:no EBP 19 statut_consult: Devis *****
# Ville:GPSN  Entreprise:Dalkia  Mission:Chaufferie
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/00-DEVIS/2025/GPSN - Dalkia - Chaufferie/Consultation/CCTP_CSPS Chaufferie du Grand-Port- rev 1.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\00-DEVIS\2025\GPSN - Dalkia - Chaufferie\Consultation\CCTP_CSPS Chaufferie du Grand-Port- rev 1.pdf</a>
#  ***** 7/101:  ID:250286 statut_consult: Chantier *****
# Ville:BERNERIE  Entreprise:LAD  Mission:PRE BOISMAIN
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/00-NOUVEAU/BERNERIE - LAD - PRE BOISMAIN/ADMINISTRATIF/Consult/CCTP_CSPS_Tranche 2 définitive.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\00-NOUVEAU\BERNERIE - LAD - PRE BOISMAIN\ADMINISTRATIF\Consult\CCTP_CSPS_Tranche 2 définitive.pdf</a>
#  ***** 8/101:  ID:220935 statut_consult: Chantier *****
# Ville:MONTOIR  Entreprise:MAIRIE  Mission:Ecole Jaurès & Multi-accueil
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/02-EN ATTENTE/MONTOIR - MAIRIE - Ecole Jaurès & Multi-accueil/ADMINISTRATIF/Consultation/EJJ-MPE CSPS CCTP.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\02-EN ATTENTE\MONTOIR - MAIRIE - Ecole Jaurès & Multi-accueil\ADMINISTRATIF\Consultation\EJJ-MPE CSPS CCTP.pdf</a>
# Doc type: CCAP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/02-EN ATTENTE/MONTOIR - MAIRIE - Ecole Jaurès & Multi-accueil/ADMINISTRATIF/Consultation/EJJ-MPE CSPS CCAP.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\02-EN ATTENTE\MONTOIR - MAIRIE - Ecole Jaurès & Multi-accueil\ADMINISTRATIF\Consultation\EJJ-MPE CSPS CCAP.pdf</a>
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/02-EN ATTENTE/MONTOIR - MAIRIE - Ecole Jaurès & Multi-accueil/ADMINISTRATIF/Consultation/EJJ-MPE CSPS RC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\02-EN ATTENTE\MONTOIR - MAIRIE - Ecole Jaurès & Multi-accueil\ADMINISTRATIF\Consultation\EJJ-MPE CSPS RC.pdf</a>
#  ***** 9/101:  ID:230152 statut_consult: Chantier *****
# Ville:CHAUMES EN RETZ  Entreprise:PORNIC AGGLO  Mission:Tx Alvéoles ISDND Écocentre Ste Anne
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/03-EN ATTENTE PHASE 2/CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne/ADMINISTRATIF/Consultation/2023_300_CCTP_SPS_Travaux_alveoles_ISDND_Ecocentre.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\03-EN ATTENTE PHASE 2\CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne\ADMINISTRATIF\Consultation\2023_300_CCTP_SPS_Travaux_alveoles_ISDND_Ecocentre.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/03-EN ATTENTE PHASE 2/CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne/ADMINISTRATIF/Consultation/Annexe CCTP marchés travaux_3LOTS/2022_308_LOT1_CCTP_travaux.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\03-EN ATTENTE PHASE 2\CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne\ADMINISTRATIF\Consultation\Annexe CCTP marchés travaux_3LOTS\2022_308_LOT1_CCTP_travaux.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/03-EN ATTENTE PHASE 2/CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne/ADMINISTRATIF/Consultation/Annexe CCTP marchés travaux_3LOTS/2022_308_LOT2_CCTP_travaux.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\03-EN ATTENTE PHASE 2\CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne\ADMINISTRATIF\Consultation\Annexe CCTP marchés travaux_3LOTS\2022_308_LOT2_CCTP_travaux.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/03-EN ATTENTE PHASE 2/CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne/ADMINISTRATIF/Consultation/Annexe CCTP marchés travaux_3LOTS/2022_308_LOT3_CCTP_travaux.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\03-EN ATTENTE PHASE 2\CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne\ADMINISTRATIF\Consultation\Annexe CCTP marchés travaux_3LOTS\2022_308_LOT3_CCTP_travaux.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/03-EN ATTENTE PHASE 2/CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne/ADMINISTRATIF/Consultation/Annexe CCTP marchés travaux_3LOTS/2022_308_Planning_CCTP_travaux - Copie1.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\03-EN ATTENTE PHASE 2\CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne\ADMINISTRATIF\Consultation\Annexe CCTP marchés travaux_3LOTS\2022_308_Planning_CCTP_travaux - Copie1.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/03-EN ATTENTE PHASE 2/CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne/ADMINISTRATIF/Consultation/Annexe CCTP marchés travaux_3LOTS/2022_308_Planning_CCTP_travaux - Copie2.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\03-EN ATTENTE PHASE 2\CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne\ADMINISTRATIF\Consultation\Annexe CCTP marchés travaux_3LOTS\2022_308_Planning_CCTP_travaux - Copie2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/03-EN ATTENTE PHASE 2/CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne/ADMINISTRATIF/Consultation/Annexe CCTP marchés travaux_3LOTS/2022_308_Planning_CCTP_travaux -1.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\03-EN ATTENTE PHASE 2\CHAUMES EN RETZ - PORNIC AGGLO - Tx Alvéoles ISDND Écocentre Ste Anne\ADMINISTRATIF\Consultation\Annexe CCTP marchés travaux_3LOTS\2022_308_Planning_CCTP_travaux -1.pdf</a>
#  ***** 10/101:  ID:no EBP 54 statut_consult: Chantier *****
# Ville:ST NAZAIRE  Entreprise:SONADEV  Mission:Zac de Brais
# Doc type: CCAP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/03-EN ATTENTE PHASE 2/ST NAZAIRE - SONADEV - Zac de Brais/Administratif/Consultation/CCAP SPS.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\03-EN ATTENTE PHASE 2\ST NAZAIRE - SONADEV - Zac de Brais\Administratif\Consultation\CCAP SPS.pdf</a>
#  ***** 11/101:  ID:18000296 statut_consult: Chantier *****
# Ville:PELLERIN  Entreprise:ATLANTIC EAU  Mission:Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE MODIFIE LE 20 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE MODIFIE LE 20 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE V2 LE 29 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE V2 LE 29 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Sébastien GOURAUD - SEBASTIEN/01-CHANTIERS/04-EN COURS/COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE MODIFIE LE 20 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Sébastien GOURAUD - SEBASTIEN\01-CHANTIERS\04-EN COURS\COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE MODIFIE LE 20 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Sébastien GOURAUD - SEBASTIEN/01-CHANTIERS/04-EN COURS/COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE V2 LE 29 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Sébastien GOURAUD - SEBASTIEN\01-CHANTIERS\04-EN COURS\COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE V2 LE 29 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
#  ***** 12/101:  ID:18000298 statut_consult: Chantier *****
# Ville:PELLERIN  Entreprise:ATLANTIC EAU  Mission:Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE MODIFIE LE 20 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE MODIFIE LE 20 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE V2 LE 29 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE V2 LE 29 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Sébastien GOURAUD - SEBASTIEN/01-CHANTIERS/04-EN COURS/COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE MODIFIE LE 20 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Sébastien GOURAUD - SEBASTIEN\01-CHANTIERS\04-EN COURS\COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE MODIFIE LE 20 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Sébastien GOURAUD - SEBASTIEN/01-CHANTIERS/04-EN COURS/COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE V2 LE 29 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Sébastien GOURAUD - SEBASTIEN\01-CHANTIERS\04-EN COURS\COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE V2 LE 29 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
#  ***** 13/101:  ID:18000297 statut_consult: Chantier *****
# Ville:PELLERIN  Entreprise:ATLANTIC EAU  Mission:Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE MODIFIE LE 20 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE MODIFIE LE 20 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE V2 LE 29 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\PELLERIN - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE V2 LE 29 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Sébastien GOURAUD - SEBASTIEN/01-CHANTIERS/04-EN COURS/COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE MODIFIE LE 20 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Sébastien GOURAUD - SEBASTIEN\01-CHANTIERS\04-EN COURS\COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE MODIFIE LE 20 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Sébastien GOURAUD - SEBASTIEN/01-CHANTIERS/04-EN COURS/COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)/Administratif/Consultation/DCE V2 LE 29 06 2018/0_RC_SPS_Feeder_Loire_v2.pdf">C:\Users\jch_m\ATAE\Sébastien GOURAUD - SEBASTIEN\01-CHANTIERS\04-EN COURS\COUERON - ATLANTIC EAU - Traversée Loire Feeder de sécurisation (DIUO) (Lot 1-2-3)\Administratif\Consultation\DCE V2 LE 29 06 2018\0_RC_SPS_Feeder_Loire_v2.pdf</a>
#  ***** 14/101:  ID:250240 statut_consult: Chantier *****
# Ville:PORNICHET  Entreprise:MAIRIE  Mission:REHAB VIEUX MOLE
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/PORNICHET - MAIRIE - REHAB VIEUX MOLE/ADMINISTRATIF/Consult/2_DCE_finalisé/2_pièces_techniques/CCTP.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\PORNICHET - MAIRIE - REHAB VIEUX MOLE\ADMINISTRATIF\Consult\2_DCE_finalisé\2_pièces_techniques\CCTP.pdf</a>
# Doc type: CCAP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/PORNICHET - MAIRIE - REHAB VIEUX MOLE/ADMINISTRATIF/Consult/2_DCE_finalisé/1_pièces_administratives/CCAP.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\PORNICHET - MAIRIE - REHAB VIEUX MOLE\ADMINISTRATIF\Consult\2_DCE_finalisé\1_pièces_administratives\CCAP.pdf</a>
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/PORNICHET - MAIRIE - REHAB VIEUX MOLE/ADMINISTRATIF/Consult/2_DCE_finalisé/1_pièces_administratives/RC.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\PORNICHET - MAIRIE - REHAB VIEUX MOLE\ADMINISTRATIF\Consult\2_DCE_finalisé\1_pièces_administratives\RC.pdf</a>
#  ***** 15/101:  ID:250275 statut_consult: Chantier *****
# Ville:TRIGNAC  Entreprise:CENTRALITES 44  Mission:Aménagmt MAM
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/TRIGNAC - CENTRALITES 44 - Aménagmt MAM/ADMINISTRATIF/Consult/CSPS - CCTP et reglement de consultation.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\TRIGNAC - CENTRALITES 44 - Aménagmt MAM\ADMINISTRATIF\Consult\CSPS - CCTP et reglement de consultation.pdf</a>
#  ***** 16/101:  ID:250427 statut_consult: Chantier *****
# Ville:TRIGNAC  Entreprise:SAS VALIMMO  Mission:Cultura parking
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Cyrille CHARTIER - CYRILLE/01-CHANTIERS/04-EN COURS/TRIGNAC - SAS VALIMMO - Cultura parking/ADMINISTRATIF/Consultation/DCE/CCTP TCE.pdf">C:\Users\jch_m\ATAE\Cyrille CHARTIER - CYRILLE\01-CHANTIERS\04-EN COURS\TRIGNAC - SAS VALIMMO - Cultura parking\ADMINISTRATIF\Consultation\DCE\CCTP TCE.pdf</a>
#  ***** 17/101:  ID:230180 statut_consult: Archive *****
# Ville:ST SEB  Entreprise:MAIRIE  Mission:luminaires bâts municipaux
#
#  ***** 18/101:  ID:230776 statut_consult: Archive *****
# Ville:VERTOU  Entreprise:SCI de l'ALLIER  Mission:Bat LCJ CAPTEURS
#
#  ***** 19/101:  ID:no EBP 231 statut_consult: Archive *****
# Ville:Plan 01  Entreprise:Masse RDC Coupes Facades  Mission:LCJ CAPTEURS Vertou.pdf
#
#  ***** 20/101:  ID:230233 statut_consult: Archive *****
# Ville:PELLERIN  Entreprise:DEPT44  Mission:Collège P&M Curie Modulaires 4 classes
#
#  ***** 21/101:  ID:240188 statut_consult: Archive *****
# Ville:ST NAZAIRE  Entreprise:NANTES UNIV  Mission:Projet filière Heinlex
#
#  ***** 22/101:  ID:no EBP 602 statut_consult: Devis *****
# Ville:DEPT85  Entreprise:DEPT85  Mission:Accord cadre Bâtiments et collèges
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/00 - CONTRAT CADRE/DEPT85 - DEPT85 - Accord cadre Bâtiments et collèges/REGION PDL AC N° 202452543 - Tx Agglo nantaise et Ancenis/Consultation/CCTP_AC_CSPS.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\00 - CONTRAT CADRE\DEPT85 - DEPT85 - Accord cadre Bâtiments et collèges\REGION PDL AC N° 202452543 - Tx Agglo nantaise et Ancenis\Consultation\CCTP_AC_CSPS.pdf</a>
# Doc type: CCAP
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/00 - CONTRAT CADRE/DEPT85 - DEPT85 - Accord cadre Bâtiments et collèges/REGION PDL AC N° 202452543 - Tx Agglo nantaise et Ancenis/Consultation/CCAP_AC_CSPS.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\00 - CONTRAT CADRE\DEPT85 - DEPT85 - Accord cadre Bâtiments et collèges\REGION PDL AC N° 202452543 - Tx Agglo nantaise et Ancenis\Consultation\CCAP_AC_CSPS.pdf</a>
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/00 - CONTRAT CADRE/DEPT85 - DEPT85 - Accord cadre Bâtiments et collèges/REGION PDL AC N° 202452543 - Tx Agglo nantaise et Ancenis/Consultation/RC_AC_CSPS.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\00 - CONTRAT CADRE\DEPT85 - DEPT85 - Accord cadre Bâtiments et collèges\REGION PDL AC N° 202452543 - Tx Agglo nantaise et Ancenis\Consultation\RC_AC_CSPS.pdf</a>
#  ***** 23/101:  ID:no EBP 606 statut_consult: Perdu *****
# Ville:CHEVROLIERE  Entreprise:ACISTE ING  Mission:Restauration église
# Doc type: CCAP
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2021/0-ECHEC 2021/CHEVROLIERE - ACISTE ING - Restauration église/Consultation/Lot 2 -SPS-CHEVROLIERE/LA CHEVROLIERE_SPS CCAP.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2021\0-ECHEC 2021\CHEVROLIERE - ACISTE ING - Restauration église\Consultation\Lot 2 -SPS-CHEVROLIERE\LA CHEVROLIERE_SPS CCAP.pdf</a>
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2021/0-ECHEC 2021/CHEVROLIERE - ACISTE ING - Restauration église/Consultation/AWS-MPI-1027315-RC.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2021\0-ECHEC 2021\CHEVROLIERE - ACISTE ING - Restauration église\Consultation\AWS-MPI-1027315-RC.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2021/0-ECHEC 2021/CHEVROLIERE - ACISTE ING - Restauration église/Consultation/Extrait RC Contenu réponse.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2021\0-ECHEC 2021\CHEVROLIERE - ACISTE ING - Restauration église\Consultation\Extrait RC Contenu réponse.pdf</a>
#  ***** 24/101:  ID:no EBP 608 statut_consult: Perdu *****
# Ville:SOULLANS  Entreprise:MAIRIE  Mission:Ilot Eglise
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2021/0-ECHEC 2021/SOULLANS - MAIRIE - Ilot Eglise/Consultation/1 RC.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2021\0-ECHEC 2021\SOULLANS - MAIRIE - Ilot Eglise\Consultation\1 RC.pdf</a>
#  ***** 25/101:  ID:no EBP 610 statut_consult: Perdu *****
# Ville:SOULLANS  Entreprise:MAIRIE  Mission:Aménagement plaine +construction complexe sport& courts tennis
# Doc type: Reglement
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/01-ECHEC 2022/SOULLANS - MAIRIE - Aménagement plaine +construction complexe sport& courts tennis/Consultation/1 RC.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\01-ECHEC 2022\SOULLANS - MAIRIE - Aménagement plaine +construction complexe sport& courts tennis\Consultation\1 RC.pdf</a>
#  ***** 26/101:  ID:no EBP 611 statut_consult: Perdu *****
# Ville:ST PHILIBERT GD.L. & STE LUMINE DE COUTAIS  Entreprise:CC  Mission:Itinéraire cyclable 87
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/01-ECHEC 2022/ST PHILIBERT GD.L. & STE LUMINE DE COUTAIS - CC  - Itinéraire cyclable 87/Consultation/1929-87-DCE-CCTP.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\01-ECHEC 2022\ST PHILIBERT GD.L. & STE LUMINE DE COUTAIS - CC  - Itinéraire cyclable 87\Consultation\1929-87-DCE-CCTP.pdf</a>
#  ***** 27/101:  ID:no EBP 612 statut_consult: Perdu *****
# Ville:VERTOU  Entreprise:MAIRIE  Mission:Construction GS Echalonnieres
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/01-ECHEC 2022/VERTOU - MAIRIE - Construction GS Echalonnieres/Consultation/PIECES_TECHNIQUES/220002_CCTP_CSPS.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\01-ECHEC 2022\VERTOU - MAIRIE - Construction GS Echalonnieres\Consultation\PIECES_TECHNIQUES\220002_CCTP_CSPS.pdf</a>
# Doc type: CCAP
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/01-ECHEC 2022/VERTOU - MAIRIE - Construction GS Echalonnieres/Consultation/PIECES_ADMINISTRATIVES/220002_CCAP.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\01-ECHEC 2022\VERTOU - MAIRIE - Construction GS Echalonnieres\Consultation\PIECES_ADMINISTRATIVES\220002_CCAP.pdf</a>
#  ***** 28/101:  ID:no EBP 613 statut_consult: Devis *****
# Ville:CHALLANS  Entreprise:SCCV BATICANA (LOTIPROMO)  Mission:Clémenceau 4 MI
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/CHALLANS - SCCV BATICANA (LOTIPROMO) - Clémenceau 4 MI/Consultation/CCTP GENERALITES.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\CHALLANS - SCCV BATICANA (LOTIPROMO) - Clémenceau 4 MI\Consultation\CCTP GENERALITES.pdf</a>
#  ***** 29/101:  ID:no EBP 614 statut_consult: Devis *****
# Ville:GETIGNE  Entreprise:LESNI  Mission:Bureaux
# Doc type: CCTP
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-000_ECO-CCTP_Lot_00_Prescriptions_communes.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-000_ECO-CCTP_Lot_00_Prescriptions_communes.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-001_ECO-CCTP_Lot_01A_Terrassements_VRD_V1-220204.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-001_ECO-CCTP_Lot_01A_Terrassements_VRD_V1-220204.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-002_ECO-CCTP_Lot_01B_Paysage_V1-220204.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-002_ECO-CCTP_Lot_01B_Paysage_V1-220204.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-003_ECO-CCTP_Lot_02_Gros_oeuvre_V1-220204.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-003_ECO-CCTP_Lot_02_Gros_oeuvre_V1-220204.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-004_ECO-CCTP_Lot_03_Charpente_Ossature_Bardage_bois_V1-220204.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-004_ECO-CCTP_Lot_03_Charpente_Ossature_Bardage_bois_V1-220204.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-005_ECO-CCTP_Lot_04_Etanchéité_Couverture.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-005_ECO-CCTP_Lot_04_Etanchéité_Couverture.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-006_ECO-CCTP_Lot_05A_Menuiseries_Extérieures_Aluminium.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-006_ECO-CCTP_Lot_05A_Menuiseries_Extérieures_Aluminium.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-007_ECO-CCTP_Lot_05B_Menuiseries_Intérieures_Aluminium.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-007_ECO-CCTP_Lot_05B_Menuiseries_Intérieures_Aluminium.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-008_ECO-CCTP_Lot_06_Serrurerie.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-008_ECO-CCTP_Lot_06_Serrurerie.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-009_ECO-CCTP_Lot_07_Menuiserie_Intérieure_Bois.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-009_ECO-CCTP_Lot_07_Menuiserie_Intérieure_Bois.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-010_ECO-CCTP_Lot_08_Cloisons_Sèches_Plafonds.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-010_ECO-CCTP_Lot_08_Cloisons_Sèches_Plafonds.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-011_ECO-CCTP_Lot_09_Chape_Revêtements_Sols.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-011_ECO-CCTP_Lot_09_Chape_Revêtements_Sols.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-012_ECO-CCTP_Lot_10_Peinture.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-012_ECO-CCTP_Lot_10_Peinture.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-013_ECO-CCTP_Lot_11_Chauf_Vent_Plomb_V1-220204.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-013_ECO-CCTP_Lot_11_Chauf_Vent_Plomb_V1-220204.pdf</a>
# <a href="file:///C:/Users/jch_m/ATAE/Eric Garnier - ERIC/00-DEVIS/2022/GETIGNE - LESNI - Bureaux/Consultation/02 - pièces techniques/02-1 pièces écrites/2004-MAR-PE-014_ECO-CCTP_Lot_12_Electricite_V1-220204.pdf">C:\Users\jch_m\ATAE\Eric Garnier - ERIC\00-DEVIS\2022\GETIGNE - LESNI - Bureaux\Consultation\02 - pièces techniques\02-1 pièces écrites\2004-MAR-PE-014_ECO-CCTP_Lot_12_Electricite_V1-220204.pdf</a>
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[14], line 48
#      46 flag_callmodel = True
#      47 if doc_type == "CCTP" or doc_type == "CCP" or doc_type == "Lettre Consult" or doc_type == "Planning" :
# ---> 48     json_result = run_genai_docs(text_input, prompt_resumer_cctp, prompt_json_cctp)
#      49     bid_utils.update_df_with_json_cctp(json_result , ebp_id, df_consult_elevated)
#      50     nb_model_called += 1
#
# Cell In[13], line 6, in run_genai_docs(text_from_file, prompt_resumer, prompt_json)
#       3 def run_genai_docs(text_from_file, prompt_resumer,prompt_json ):
#       4     #Resumer
#       5     prompt_full_r = prompt_resumer + text_from_file
# ----> 6     result = Genaiclient.models.generate_content(model=MODEL_ID,  contents=prompt_full_r)
#       7     #bid_utils.print_text_wrapped(f"\nLLM response pour resumer: \n" + result.text)
#       8
#       9     #JSON
#      10     prompt_full_j = prompt_json + result.text
#
# File c:\DocPerso\Dev_Python\ProjetsPerso\BidManagement\.env_bid\Lib\site-packages\google\genai\models.py:6058, in Models.generate_content(self, model, contents, config)
#    6056 while remaining_remote_calls_afc > 0:
#    6057   i += 1
# -> 6058   response = self._generate_content(
#    6059       model=model, contents=contents, config=parsed_config
#    6060   )
#    6061   logger.info(f'AFC remote call {i} is done.')
#    6062   remaining_remote_calls_afc -= 1
#
# File c:\DocPerso\Dev_Python\ProjetsPerso\BidManagement\.env_bid\Lib\site-packages\google\genai\models.py:5007, in Models._generate_content(self, model, contents, config)
#    5004 request_dict = _common.convert_to_dict(request_dict)
#    5005 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5007 response_dict = self._api_client.request(
#    5008     'post', path, request_dict, http_options
#    5009 )
#    5011 if self._api_client.vertexai:
#    5012   response_dict = _GenerateContentResponse_from_vertex(
#    5013       self._api_client, response_dict
#    5014   )
#
# File c:\DocPerso\Dev_Python\ProjetsPerso\BidManagement\.env_bid\Lib\site-packages\google\genai\_api_client.py:927, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#     917 def request(
#     918     self,
#     919     http_method: str,
#    (...)    922     http_options: Optional[HttpOptionsOrDict] = None,
#     923 ) -> Union[BaseResponse, Any]:
#     924   http_request = self._build_request(
#     925       http_method, path, request_dict, http_options
#     926   )
# --> 927   response = self._request(http_request, stream=False)
#     928   json_response = response.json
#     929   if not json_response:
#
# File c:\DocPerso\Dev_Python\ProjetsPerso\BidManagement\.env_bid\Lib\site-packages\google\genai\_api_client.py:793, in BaseApiClient._request(self, http_request, stream)
#     785 else:
#     786   response = self._httpx_client.request(
#     787       method=http_request.method,
#     788       url=http_request.url,
#    (...)    791       timeout=http_request.timeout,
#     792   )
# --> 793   errors.APIError.raise_for_response(response)
#     794   return HttpResponse(
#     795       response.headers, response if stream else [response.text]
#     796   )
#
# File c:\DocPerso\Dev_Python\ProjetsPerso\BidManagement\.env_bid\Lib\site-packages\google\genai\errors.py:104, in APIError.raise_for_response(cls, response)
#     102 status_code = response.status_code
#     103 if 400 <= status_code < 500:
# --> 104   raise ClientError(status_code, response_json, response)
#     105 elif 500 <= status_code < 600:
#     106   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '250000'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '24s'}]}}

# %%
print("nb of count_ebp_model",count_ebp_model)
print("nb of nb_model_called",nb_model_called, "\n")

#f_consult_ebp.loc[consult_mask].head()
df_consult_elevated.loc[consult_mask].info()
# Out:
# nb of count_ebp_model 28
# nb of nb_model_called 32
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 926 entries, 0 to 158400
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   SPS Name                             926 non-null    object
#  1   Ville                                926 non-null    object
#  2   Entreprise                           926 non-null    object
#  3   Mission                              926 non-null    object
#  4   statut_consult                       926 non-null    object
#  5   ID EBP                               926 non-null    object
#  6   regl crit-prix                       11 non-null     float64
#  7   regl crit-tech global                11 non-null     float64
#  8   regl duree-travaux                   11 non-null     float64
#  9   regl prix travaux                    11 non-null     float64
#  10  regl crit-tech-moyen_humain          11 non-null     float64
#  11  regl crit-tech-methodologie          11 non-null     float64
#  12  regl crit-tech-coherence_temps       11 non-null     float64
#  13  regl crit-tech-comprehension_enjeux  11 non-null     float64
#  14  cctp nom_chantier                    14 non-null     object
#  15  cctp lieu                            14 non-null     object
#  16  cctp type travaux                    14 non-null     object
#  17  cctp duree travaux                   14 non-null     float64
#  18  cctp planning conception             11 non-null     object
#  19  cctp prix travaux                    14 non-null     float64
#  20  cctp maitre ouvrage                  14 non-null     object
#  21  cctp maitre oeuvre                   11 non-null     object
#  22  cctp cat SPS                         12 non-null     object
#  23  aapc mission                         1 non-null      object
#  24  aapc lieu                            1 non-null      object
#  25  aapc m_ouvrage                       1 non-null      object
#  26  aapc tot                             1 non-null      object
#  27  aapc tranche                         1 non-null      object
#  28  aapc prix_travaux                    1 non-null      float64
#  29  aapc duree_travaux                   1 non-null      float64
#  30  ccap objet                           6 non-null      object
#  31  ccap lieu                            6 non-null      object
#  32  ccap m_ouvrage                       5 non-null      object
#  33  ccap m_oeuvre                        3 non-null      object
#  34  ccap lot                             6 non-null      object
# dtypes: float64(12), object(23)
# memory usage: 260.4+ KB

# %%
df_consult_elevated.columns
# Out:
# Index(['SPS Name', 'Ville', 'Entreprise', 'Mission', 'statut_consult',
#        'ID EBP', 'regl crit-prix', 'regl crit-tech global',
#        'regl duree-travaux', 'regl prix travaux',
#        'regl crit-tech-moyen_humain', 'regl crit-tech-methodologie',
#        'regl crit-tech-coherence_temps', 'regl crit-tech-comprehension_enjeux',
#        'cctp nom_chantier', 'cctp lieu', 'cctp type travaux',
#        'cctp duree travaux', 'cctp planning conception', 'cctp prix travaux',
#        'cctp maitre ouvrage', 'cctp maitre oeuvre', 'cctp cat SPS',
#        'aapc mission', 'aapc lieu', 'aapc m_ouvrage', 'aapc tot',
#        'aapc tranche', 'aapc prix_travaux', 'aapc duree_travaux', 'ccap objet',
#        'ccap lieu', 'ccap m_ouvrage', 'ccap m_oeuvre', 'ccap lot'],
#       dtype='object')

# %%
# show key info per columns
keywords = ['cctp', 'aapc', 'regl', 'ccp']
list_col_added = [col for col in df_consult_elevated.columns if any(keyword in col for keyword in keywords)]
mask_non_null = df_consult_elevated[list_col_added].map(lambda x: pd.notna(x) and (x != 0 or x != ""))
count_non_null_rows = mask_non_null.any(axis=1).sum()

filtered_df = df_consult_elevated[mask_non_null.any(axis=1)]
TableReport(filtered_df)
# Out:
# Processing column  35 / 35
# <TableReport: use .open() to display>

# %%
# Save the DataFrame to a pickle file

df_consult_elevated.to_pickle(path_df_consult_elevated)
print(f"\nDataFrame successfully saved to '{path_df_consult_elevated}'")
# Out:
# DataFrame successfully saved to 'C:\Users\jch_m\ATAE\Nicolas MONCEAU - NICOLAS\Stage_AppelsOffres\data_output\df_consult_elevated.pkl'
